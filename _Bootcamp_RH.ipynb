# %% [markdown]
# # Recursos Humanos (RH)

# %% [markdown]
# ## Definição dos Atributos
#
# **Matricula**: Identificador único de cada funcionário, gerado como um código numérico de 4 dígitos, começando de "0001" até "1000".
#
# **N**ome: Nome fictício do funcionário, no formato "Funcionário N", onde N varia de 1 a 1000. Este campo é meramente representativo.
#
# **Genero**: Categoria de gênero, contendo valores "Masculino", "Feminino" ou "Não Informado", com distribuição aleatória entre os funcionários.
#
# **Departamento**: Setor ao qual o funcionário pertence, distribuído entre as categorias: Financeiro; RH (Recursos Humanos); TI (Tecnologia da Informação); Marketing; Operações. Em alguns registros, valores nulos foram inseridos para simular casos onde o departamento pode não estar especificado.
#
# **Cargo**: Posição ou função do funcionário dentro da empresa, compatível com o departamento. As categorias de cargos são: Analista; Gerente; Assistente; Diretor; Coordenador. Há registros com valores nulos para simular dados incompletos.
#
# **Formacao**: Formação acadêmica do funcionário, relacionada ao departamento Departamentos e suas formações associadas: Financeiro: Contabilidade, Administração, Economia; RH: Psicologia, Administração, Recursos Humanos; TI: Engenharia da Computação, Ciência da Computação, Sistemas de Informação
# Marketing: Marketing, Publicidade e Propaganda, Comunicação Social; Operações: Engenharia de Produção, Logística, Administração. Valores nulos foram inseridos para simular lacunas nesses dados.
#
# **Escolaridade**: Nível de escolaridade do funcionário, com categorias que incluem: Ensino Médio; Tecnólogo; Graduação; Pós-graduação; Mestrado. Distribuição aleatória sem relação direta com o cargo ou departamento. Este campo não possui valores nulos.
#
# **Salario_Bruto**: Valor bruto do salário do funcionário, gerado com uma média de RS 5.000,00 e desvio padrão de RS 1.500,00. Mas, inclui alguns valores nulos para simular registros incompletos. Em cerca de 1% dos casos, valores atípicos foram inseridos (outliers), aumentando o salário para até 10 ou 15 vezes o valor original.
#
# Horas_Trabalhadas: Número médio de horas trabalhadas no mês, com média de 160 horas e desvio padrão de 20 horas. Em alguns registros, outliers foram adicionados, aumentando as horas trabalhadas para até 5 ou 10 vezes o valor típico, e valores nulos foram inseridos para simular dados faltantes.
#
# **Bonificacao**: Valor das bonificações recebidas pelos funcionários, com média de RS 500,00 e desvio padrão de RS 200,00. Outliers foram inseridos em cerca de 1% dos casos, aumentando o valor da bonificação em até 3 ou 5 vezes. Há também valores nulos, indicando registros sem informações de bonificação. Algumas bonificações estão com valores negativos devido a política da empresa que caso o funcionário receba a bonificação antecipada ou houve necessidade de corrigir algum valor.

# %% [markdown]
# ## Pipeline
#
# Etapa 01: Instalar e Importar as Bibliotecas
#
# Etapa 02: Obter o Datasource
#
# Etapa 03: Exibir os Dados, Metadados e Estatísticas
#
# Etapa 04: Extract, Transform, Load (ETL)
#
# Etapa 05: Exploratory Data Analysis (EDA)
#
# Etapa 06: Identificação dos Outliers
#
# Etapa 07: Clusterização
#
# Etapa 08: Rotulagem
#
# Etapa 09: Preprocess
#
# Etapa 10: Balanceamento dos Dados
#
# Etapa 11: Separação dos Dados para Treinamento/Teste e Validação
#
# Etapa 12: Competição dos Modelos

# %% [markdown]
# ## Etapa 1: Instalar e Importar as Bibliotecas

# %%
# Importar bibliotecas
try:
  import gdown
except ImportError:
  # !pip install gdown
  import gdown
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.ensemble import IsolationForest
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.utils import resample
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score, train_test_split
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## Etapa 2: Obter o Datasource

# %%
# Atribuir ID do arquivo no Google Drive
file_id = '1H8rY6yZqAhfiNSPZ2_0JCn-2HqUlJ-rI'
dataset_url = f'https://drive.google.com/uc?id={file_id}'

# Definir nome do arquivo
output_path = 'rh.csv'

# Baixar o arquivo usando gdown
gdown.download(dataset_url, output_path, quiet=False)

# Carregar o arquivo CSV em um DataFrame, especificando o separador como ponto-e-vírgula
dataset = pd.read_csv(output_path, sep=';')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1H8rY6yZqAhfiNSPZ2_0JCn-2HqUlJ-rI
# To: /content/rh.csv
# 100%|██████████| 96.9k/96.9k [00:00<00:00, 7.19MB/s]

# %% [markdown]
# ## Etapa 3: Exibir os Dados, Metadados e Estatísticas

# %%
# Explorar os metadados do dataset
print("Exploração dos Metadados do Dataset")

# Exibir o DataFrame
print("Dados do Dataset:")
print(dataset.head().to_string())
# Out:
# Exploração dos Metadados do Dataset
# Dados do Dataset:
#    Matricula           Nome         Genero Departamento        Cargo                Formacao   Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 0          1  Funcionário 1       Feminino    Operações      Diretor  Engenharia de Produção  Pós-graduação            NaN              139.9       315.92
# 1          2  Funcionário 2       Feminino   Financeiro     Analista           Administração  Pós-graduação        5128.93              117.1       467.94
# 2          3  Funcionário 3  Não Informado    Marketing   Assistente               Marketing       Mestrado        6127.92              195.9          NaN
# 3          4  Funcionário 4  Não Informado    Marketing  Coordenador               Marketing      Tecnólogo        5844.48              155.9       199.47
# 4          5  Funcionário 5  Não Informado    Marketing      Gerente      Comunicação Social      Graduação        3207.52              151.0       318.89

# %%
# Obter informações gerais do dataset
print("Informações Gerais do Dataset:")
print(dataset.info())
# Out:
# Informações Gerais do Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Matricula          1000 non-null   int64
#  1   Nome               1000 non-null   object
#  2   Genero             1000 non-null   object
#  3   Departamento       900 non-null    object
#  4   Cargo              900 non-null    object
#  5   Formacao           900 non-null    object
#  6   Escolaridade       1000 non-null   object
#  7   Salario_Bruto      900 non-null    float64
#  8   Horas_Trabalhadas  900 non-null    float64
#  9   Bonificacao        900 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.2+ KB
# None

# %%
# Exibir o número de linhas e colunas
print("Dimensões do Dataset (Linhas, Colunas):")
print(dataset.shape)
# Out:
# Dimensões do Dataset (Linhas, Colunas):
# (1000, 10)

# %%
# Exibir o nome das colunas
print("Nomes das Colunas:")
print(dataset.columns.tolist())
# Out:
# Nomes das Colunas:
# ['Matricula', 'Nome', 'Genero', 'Departamento', 'Cargo', 'Formacao', 'Escolaridade', 'Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao']

# %%
# Checar dados ausentes por coluna
print("Dados Ausentes por Coluna:")
print(dataset.isnull().sum())
# Out:
# Dados Ausentes por Coluna:
# Matricula              0
# Nome                   0
# Genero                 0
# Departamento         100
# Cargo                100
# Formacao             100
# Escolaridade           0
# Salario_Bruto        100
# Horas_Trabalhadas    100
# Bonificacao          100
# dtype: int64

# %%
# Exibir tipos de dados de cada coluna
print("Tipos de Dados das Colunas:")
print(dataset.dtypes)
# Out:
# Tipos de Dados das Colunas:
# Matricula              int64
# Nome                  object
# Genero                object
# Departamento          object
# Cargo                 object
# Formacao              object
# Escolaridade          object
# Salario_Bruto        float64
# Horas_Trabalhadas    float64
# Bonificacao          float64
# dtype: object

# %%
# Exibir estatísticas descritivas para colunas numéricas
print("Estatísticas Descritivas das Colunas Numéricas:")
print(dataset.describe().to_string())
# Out:
# Estatísticas Descritivas das Colunas Numéricas:
#          Matricula  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# count  1000.000000     900.000000         900.000000   900.000000
# mean    500.500000    5599.508789         175.209222   516.953511
# std     288.819436    6852.542095         161.033291   284.804903
# min       1.000000     324.720000         103.800000  -248.020000
# 25%     250.750000    3911.505000         145.300000   357.205000
# 50%     500.500000    5027.105000         158.800000   505.950000
# 75%     750.250000    5971.157500         171.700000   644.985000
# max    1000.000000   88485.750000        2067.000000  3441.350000

# %%
# Exibir domínios por coluna para colunas categóricas
print("Domínios por Coluna Categórica:")
for col in dataset.select_dtypes(include=['object']).columns:
    print(f"{col}: {dataset[col].nunique()} valores únicos")
# Out:
# Domínios por Coluna Categórica:
# Nome: 1000 valores únicos
# Genero: 3 valores únicos
# Departamento: 5 valores únicos
# Cargo: 5 valores únicos
# Formacao: 13 valores únicos
# Escolaridade: 6 valores únicos

# %%
# Exibir domínios por coluna para colunas categóricas, excluindo a coluna 'Nome'
print("Valores únicos dos domínios por Coluna Categórica:")
for col in dataset.select_dtypes(include=['object']).columns:
  if col != 'Nome':
    print(f"Valores únicos da coluna '{col}':")
    print(dataset[col].unique())
# Out:
# Valores únicos dos domínios por Coluna Categórica:
# Valores únicos da coluna 'Genero':
# ['Feminino' 'Não Informado' 'Masculino']
# Valores únicos da coluna 'Departamento':
# ['Operações' 'Financeiro' 'Marketing' 'RH' 'TI' nan]
# Valores únicos da coluna 'Cargo':
# ['Diretor' 'Analista' 'Assistente' 'Coordenador' 'Gerente' nan]
# Valores únicos da coluna 'Formacao':
# ['Engenharia de Produção' 'Administração' 'Marketing' 'Comunicação Social'
#  'Psicologia' 'Engenharia da Computação' 'Economia' 'Logística'
#  'Recursos Humanos' nan 'Sistemas de Informação'
#  'Publicidade e Propaganda' 'Contabilidade' 'Ciência da Computação']
# Valores únicos da coluna 'Escolaridade':
# ['Pós-graduação' 'Mestrado' 'Tecnólogo' 'Graduação' 'Ensino Médio'
#  'Doutorado']

# %% [markdown]
# ## Etapa 4: Extract, Transform, Load (ETL)

# %%
# Preencher valores nulos em 'Departamento' com a moda
departamento_moda = dataset['Departamento'].mode()[0]
dataset['Departamento'] = dataset['Departamento'].fillna(departamento_moda)

# Preencher valores nulos em 'Cargo' com a moda
cargo_moda = dataset['Cargo'].mode()[0]
dataset['Cargo'] = dataset['Cargo'].fillna(cargo_moda)

# Preencher valores nulos em 'Formacao' com a moda
formacao_moda = dataset['Formacao'].mode()[0]
dataset['Formacao'] = dataset['Formacao'].fillna(formacao_moda)

# Preencher valores nulos em 'Salario_Bruto' com a média
salario_medio = dataset['Salario_Bruto'].mean()
dataset['Salario_Bruto'] = dataset['Salario_Bruto'].fillna(salario_medio)

# Preencher valores nulos em 'Horas_Trabalhadas' com a média
horas_trabalhadas_media = dataset['Horas_Trabalhadas'].mean()
dataset['Horas_Trabalhadas'] = dataset['Horas_Trabalhadas'].fillna(horas_trabalhadas_media)

# Preencher valores nulos em 'Bonificacao' com o mínimo
bonificacao_min = dataset['Bonificacao'].min()
dataset['Bonificacao'] = dataset['Bonificacao'].fillna(bonificacao_min)

# Exibir os dados após a substituição
print("\nValores nulos após a substituição:")
print(dataset.isnull().sum())

# Exibir o dataset atualizado para confirmar as transformações
print("\nDataset atualizado:")
print(dataset.head().to_string())
# Out:
# Valores nulos após a substituição:
# Matricula            0
# Nome                 0
# Genero               0
# Departamento         0
# Cargo                0
# Formacao             0
# Escolaridade         0
# Salario_Bruto        0
# Horas_Trabalhadas    0
# Bonificacao          0
# dtype: int64
#
# Dataset atualizado:
#    Matricula           Nome         Genero Departamento        Cargo                Formacao   Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 0          1  Funcionário 1       Feminino    Operações      Diretor  Engenharia de Produção  Pós-graduação    5599.508789              139.9       315.92
# 1          2  Funcionário 2       Feminino   Financeiro     Analista           Administração  Pós-graduação    5128.930000              117.1       467.94
# 2          3  Funcionário 3  Não Informado    Marketing   Assistente               Marketing       Mestrado    6127.920000              195.9      -248.02
# 3          4  Funcionário 4  Não Informado    Marketing  Coordenador               Marketing      Tecnólogo    5844.480000              155.9       199.47
# 4          5  Funcionário 5  Não Informado    Marketing      Gerente      Comunicação Social      Graduação    3207.520000              151.0       318.89

# %% [markdown]
# ## Etapa 5: Exploratory Data Analysis (EDA)

# %%
# Exibir Metadados
print("\nTipos de Dados das Colunas:")
print(dataset.dtypes)

# Plotar
plt.figure(figsize=(10, 6))
plt.scatter(dataset['Matricula'], dataset['Salario_Bruto'])
plt.xlabel('Identificador')
plt.ylabel('Idade')
plt.title('Gráfico de Dispersão: Matrícula vs Salário')
plt.grid(True)
plt.show()
# Out:
# Tipos de Dados das Colunas:
# Matricula              int64
# Nome                  object
# Genero                object
# Departamento          object
# Cargo                 object
# Formacao              object
# Escolaridade          object
# Salario_Bruto        float64
# Horas_Trabalhadas    float64
# Bonificacao          float64
# dtype: object

# %%
# Criar gráficos de dispersão
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.scatter(dataset['Matricula'], dataset['Salario_Bruto'])
plt.xlabel('Matrícula')
plt.ylabel('Salário Bruto')
plt.title('Salário Bruto vs Matrícula')

plt.subplot(1, 3, 2)
plt.scatter(dataset['Matricula'], dataset['Horas_Trabalhadas'])
plt.xlabel('Matrícula')
plt.ylabel('Horas Trabalhadas')
plt.title('Horas Trabalhadas vs Matrícula')

plt.subplot(1, 3, 3)
plt.scatter(dataset['Matricula'], dataset['Bonificacao'])
plt.xlabel('Matrícula')
plt.ylabel('Bonificação')
plt.title('Bonificação vs Matrícula')

plt.tight_layout()
plt.show()

# %%
# Gráfico de barras
genero_counts = dataset['Genero'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(genero_counts.index, genero_counts.values)
plt.xlabel('Gênero')
plt.ylabel('Número de Matrículas')
plt.title('Distribuição de Matrículas por Gênero')
plt.tight_layout()
plt.show()

# %%
# Gráfico de barras
departamento_counts = dataset['Departamento'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(departamento_counts.index, departamento_counts.values)
plt.xlabel('Departamento')
plt.ylabel('Número de Funcionários')
plt.title('Distribuição dos Funcionários por Departamento')
plt.xticks(rotation=45, ha='right')  # Rotacionar rótulos do eixo x para melhor visualização
plt.tight_layout()
plt.show()

# %%
# Gráfico de barras
cargo_counts = dataset['Cargo'].value_counts()
plt.bar(cargo_counts.index, cargo_counts.values)
plt.xlabel('Cargo')
plt.ylabel('Número de Funcionários')
plt.title('Distribuição dos Funcionários por Cargo')
plt.xticks(rotation=45, ha='right')  # Rotacionar rótulos do eixo x para melhor visualização
plt.tight_layout()
plt.show()

# %%
# Gráfico de barras
formacao_counts = dataset['Formacao'].value_counts()
plt.bar(formacao_counts.index, formacao_counts.values)
plt.xlabel('Formação')
plt.ylabel('Número de Funcionários')
plt.title('Distribuição dos Funcionários por Formação')
plt.xticks(rotation=45, ha='right')  # Rotacionar rótulos do eixo x para melhor visualização
plt.tight_layout()
plt.show()

# %%
# Gráfico de barras
escolaridade_counts = dataset['Escolaridade'].value_counts()
plt.bar(escolaridade_counts.index, escolaridade_counts.values)
plt.xlabel('Escolaridade')
plt.ylabel('Número de Funcionários')
plt.title('Distribuição dos Funcionários por Escolaridade')
plt.xticks(rotation=45, ha='right')  # Rotacionar rótulos do eixo x para melhor visualização
plt.tight_layout()
plt.show()

# %%
# Selecionar features relevantes para análise, excluindo 'Matricula' e 'Nome'
features = dataset.drop(['Matricula', 'Nome', 'Salario_Bruto'], axis=1)
target = dataset['Salario_Bruto']

# Converter variáveis categóricas para numéricas usando one-hot encoding
features = pd.get_dummies(features)

# Selecionar as melhores features usando SelectKBest e f_regression
selector = SelectKBest(score_func=f_regression, k='all')
X_new = selector.fit_transform(features, target)

# Criar um DataFrame com as features selecionadas e seus scores
scores = pd.DataFrame({'Feature': features.columns, 'Score': selector.scores_})
scores = scores.sort_values(by='Score', ascending=False)


# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(scores['Feature'], scores['Score'])
plt.xlabel('Features')
plt.ylabel('Score')
plt.title('Importância das Features para Previsão de Salário Bruto')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Explicação**: Features com alta correlação entre si podem ser consideradas redundantes. Se 'Horas_Trabalhadas' e 'Bonificacao' tiverem alta correlação, deve-se remover uma delas, pois ambas podem estar representando informações semelhantes.

# %% [markdown]
# ## Etapa 6: Identificação dos Outliers

# %% [markdown]
# ### Calcular Contaminação
#
# **Explicação**: Para calcular o percentual de contaminação de outliers em um dataset, se pode usar o método InterQuartile Range (IQR) que serve para identificar os valores atípicos em cada coluna numérica. O IQR define outliers como valores que estão:
#
# Abaixo de Q1 - 1.5 x IQR
#
# ou
#
# Acima de Q3 + 1.5 x IQR

# %%
# Definir o limite
limite = 1.5

# Selecionar apenas colunas numéricas
numeric_cols = dataset.select_dtypes(include='number')

# Inicializar contador de outliers
outlier_counts = 0
total_values = numeric_cols.size

# Detectar outliers usando o método IQR para cada coluna numérica
for col in numeric_cols.columns:
    Q1 = numeric_cols[col].quantile(0.25)
    Q3 = numeric_cols[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - limite * IQR
    upper_bound = Q3 + limite * IQR

    # Contar outliers
    col_outliers = numeric_cols[(numeric_cols[col] < lower_bound) | (numeric_cols[col] > upper_bound)][col].count()
    outlier_counts += col_outliers
    print(f"Coluna '{col}' - Outliers: {col_outliers} ({(col_outliers / len(dataset) * 100):.2f}%)")

# Calcular o percentual de contaminação de outliers no dataset
outlier_percentage = (outlier_counts / total_values) * 100

print(f"\nPercentual de contaminação de outliers no dataset: {outlier_percentage:.2f}%")
print(f"Valor de contaminação de outliers no dataset: {outlier_percentage/100:.4f}%")
# Out:
# Coluna 'Matricula' - Outliers: 0 (0.00%)
# Coluna 'Salario_Bruto' - Outliers: 25 (2.50%)
# Coluna 'Horas_Trabalhadas' - Outliers: 12 (1.20%)
# Coluna 'Bonificacao' - Outliers: 109 (10.90%)
#
# Percentual de contaminação de outliers no dataset: 3.65%
# Valor de contaminação de outliers no dataset: 0.0365%

# %% [markdown]
# ### Exibição do Boxplot

# %%
# Criar boxplot para cada coluna numérica para visualizar outliers
plt.figure(figsize=(15, 10))
for i, col in enumerate(dataset.select_dtypes(include='number').columns):
    plt.subplot(3, 3, i + 1)
    plt.boxplot(dataset[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Explicação**: Mediana (linha laranja no meio da caixa): representa a mediana do dado analisado, indicando que o 50% dos dados estão abaixo desse valor e 50% estão acima.
#
# Quartis (Q1 e Q3): a parte inferior da caixa representa o primeiro quartil (Q1), que é o valor abaixo do qual estão 25% dos dados e a parte superior da caixa representa o terceiro quartil (Q3), que é o valor abaixo do qual estão 75% dos dados.
#
# Intervalo Interquartil (IQR): é a altura da caixa representa, que representa a diferença entre Q3 e Q1. Esse intervalo cobre os 50% centrais dos dados.
#
# Limites (Bigodes): são as linhas verticais que se estendem até os valores que estão dentro de 1.5 x IQR de Q1 e Q3, sendo os limites para valores considerados "normais", pois os valores fora desses limites são considerados outliers.
#
# Outliers (círculos acima da caixa): serve para indicar que existem outliers, representando dados que estão bem acima da maioria dos demais, sendo assim, considerados valores extremos. Esses pontos representam indivíduos (observações) muito acima do restante do conjunto de dados.

# %% [markdown]
# ### Visualização da distribuição dos dados outliers e inliers

# %%
# Criar modelo IsolationForest para detectar outliers
model = IsolationForest(contamination=outlier_percentage/100)  # Ajustar a contaminação conforme necessário
model.fit(dataset[['Salario_Bruto']])

# Prever se cada ponto é um outlier (-1) ou um inlier (1)
outlier_predictions = model.predict(dataset[['Salario_Bruto']])

# Criar um gráfico de dispersão com os outliers destacados
plt.figure(figsize=(10, 6))
plt.scatter(dataset['Matricula'], dataset['Salario_Bruto'], color='blue', label='Inliers')
plt.scatter(dataset['Matricula'][outlier_predictions == -1], dataset['Salario_Bruto'][outlier_predictions == -1], color='red', label='Outliers')
plt.xlabel('Matrícula')
plt.ylabel('Salário Bruto')
plt.title('Gráfico de Dispersão: Matrícula vs Salário Bruto (Outliers em Vermelho)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Criar modelo IsolationForest para detectar outliers
model = IsolationForest(contamination=outlier_percentage/100)  # Ajustar a contaminação conforme necessário
model.fit(dataset[['Horas_Trabalhadas']])

# Prever se cada ponto é um outlier (-1) ou um inlier (1)
outlier_predictions = model.predict(dataset[['Horas_Trabalhadas']])

# Criar gráfico de dispersão com os outliers destacados
plt.figure(figsize=(10, 6))
plt.scatter(dataset['Matricula'], dataset['Horas_Trabalhadas'], color='blue', label='Inliers')
plt.scatter(dataset['Matricula'][outlier_predictions == -1], dataset['Horas_Trabalhadas'][outlier_predictions == -1], color='red', label='Outliers')
plt.xlabel('Matrícula')
plt.ylabel('Horas Trabalhada')
plt.title('Gráfico de Dispersão: Matrícula vs Horas Trabalhadas (Outliers em Vermelho)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Criar modelo IsolationForest para detectar outliers
model = IsolationForest(contamination=outlier_percentage/100)  # Ajustar a contaminação conforme necessário
model.fit(dataset[['Bonificacao']])

# Prever se cada ponto é um outlier (-1) ou um inlier (1)
outlier_predictions = model.predict(dataset[['Bonificacao']])

# Criar gráfico de dispersão com os outliers destacados
plt.figure(figsize=(10, 6))
plt.scatter(dataset['Matricula'], dataset['Bonificacao'], color='blue', label='Inliers')
plt.scatter(dataset['Matricula'][outlier_predictions == -1], dataset['Bonificacao'][outlier_predictions == -1], color='red', label='Outliers')
plt.xlabel('Matrícula')
plt.ylabel('Bonificação')
plt.title('Gráfico de Dispersão: Matrícula vs Bonificação (Outliers em Vermelho)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Contar a quantidade de valores negativos em cada coluna numérica
negative_counts = (dataset.select_dtypes(include='number') < 0).sum()

# Exibir a quantidade de valores negativos por coluna
print("\nQuantidade de valores negativos por coluna:")
print(negative_counts)

# Exibir o total de valores negativos no dataset
total_negative_values = negative_counts.sum()
print(f"\nTotal de valores negativos no dataset: {total_negative_values}")
# Out:
# Quantidade de valores negativos por coluna:
# Matricula              0
# Salario_Bruto          0
# Horas_Trabalhadas      0
# Bonificacao          105
# dtype: int64
#
# Total de valores negativos no dataset: 105

# %% [markdown]
# ### Separação dos Outliers dos Inliers

# %%
# Selecionar apenas colunas numéricas para a detecção de outliers
numeric_data = dataset.select_dtypes(include='number')

# Configurar e aplicar o Isolation Forest com contaminação
iso_forest = IsolationForest(contamination=0.0365, random_state=42)
outlier_labels = iso_forest.fit_predict(numeric_data)

# Adicionar os rótulos de outliers ao dataset
dataset['is_outlier'] = outlier_labels

# Filtrar apenas os outliers (rótulo -1)
outliers = dataset[dataset['is_outlier'] == -1]

# Exibir os dados que são outliers
print("Dados identificados como outliers:")
print(outliers.to_string())

# Exibir a quantidade e percentual de outliers detectados
outlier_count = len(outliers)
outlier_percentage = (outlier_count / len(dataset)) * 100
print(f"\nTotal de outliers: {outlier_count} ({outlier_percentage:.2f}%)")
# Out:
# Dados identificados como outliers:
#      Matricula              Nome         Genero Departamento        Cargo                  Formacao   Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao  is_outlier
# 2            3     Funcionário 3  Não Informado    Marketing   Assistente                 Marketing       Mestrado    6127.920000         195.900000      -248.02          -1
# 16          17    Funcionário 17  Não Informado           RH     Analista             Administração  Pós-graduação    5599.508789         182.100000      1076.29          -1
# 19          20    Funcionário 20      Masculino    Operações     Analista                 Logística   Ensino Médio    7605.160000         188.200000       803.70          -1
# 42          43    Funcionário 43       Feminino           TI  Coordenador     Ciência da Computação       Mestrado     833.960000         175.209222       441.53          -1
# 50          51    Funcionário 51  Não Informado           RH      Diretor                Psicologia       Mestrado    5758.080000         123.200000      -248.02          -1
# 53          54    Funcionário 54      Masculino   Financeiro     Analista             Administração   Ensino Médio    8365.400000         175.209222        83.35          -1
# 108        109   Funcionário 109      Masculino           TI     Analista     Ciência da Computação   Ensino Médio    4417.770000         121.100000      -248.02          -1
# 174        175   Funcionário 175  Não Informado           TI     Analista  Engenharia da Computação  Pós-graduação   63241.050000        1549.000000      1521.80          -1
# 204        205   Funcionário 205       Feminino    Marketing   Assistente                 Marketing      Graduação     796.700000         178.800000       809.33          -1
# 232        233   Funcionário 233  Não Informado    Marketing     Analista  Publicidade e Propaganda  Pós-graduação     508.080000         177.900000       509.02          -1
# 250        251   Funcionário 251  Não Informado    Operações     Analista             Administração   Ensino Médio   77532.600000        1845.000000      3331.90          -1
# 310        311   Funcionário 311       Feminino    Operações   Assistente             Administração  Pós-graduação    5599.508789        1468.000000       684.10          -1
# 367        368   Funcionário 368  Não Informado    Marketing     Analista  Publicidade e Propaganda      Graduação    6336.010000         120.900000      -248.02          -1
# 368        369   Funcionário 369      Masculino           RH     Analista          Recursos Humanos  Pós-graduação   86540.700000        1659.000000      -248.02          -1
# 387        388   Funcionário 388       Feminino   Financeiro   Assistente             Contabilidade      Graduação   71627.400000        1597.000000      2601.05          -1
# 512        513   Funcionário 513  Não Informado           RH   Assistente             Administração   Ensino Médio   88485.750000        1736.000000      1823.55          -1
# 521        522   Funcionário 522      Masculino   Financeiro   Assistente             Contabilidade      Graduação    7750.150000         192.100000        67.27          -1
# 533        534   Funcionário 534       Feminino    Marketing   Assistente             Administração      Graduação    2241.730000         140.200000      -248.02          -1
# 624        625   Funcionário 625      Masculino           RH   Assistente             Administração   Ensino Médio   70492.050000        1422.000000      2650.05          -1
# 647        648   Funcionário 648  Não Informado           TI     Analista    Sistemas de Informação      Graduação   61313.400000        2067.000000      3441.35          -1
# 703        704   Funcionário 704       Feminino    Operações     Analista             Administração   Ensino Médio    1814.160000         136.400000      -248.02          -1
# 728        729   Funcionário 729       Feminino    Marketing   Assistente             Administração  Pós-graduação   85263.450000        1836.000000      3207.85          -1
# 733        734   Funcionário 734      Masculino           TI   Assistente    Sistemas de Informação   Ensino Médio    8297.440000         175.209222      -248.02          -1
# 776        777   Funcionário 777       Feminino   Financeiro     Analista             Administração  Pós-graduação    5599.508789        1532.000000      1031.65          -1
# 804        805   Funcionário 805  Não Informado           RH     Analista             Administração      Tecnólogo     324.720000         176.800000       449.36          -1
# 806        807   Funcionário 807  Não Informado           RH      Gerente          Recursos Humanos   Ensino Médio    2129.390000         103.800000       132.09          -1
# 855        856   Funcionário 856      Masculino           TI   Assistente     Ciência da Computação      Tecnólogo    7073.270000         135.600000      -248.02          -1
# 868        869   Funcionário 869       Feminino    Marketing   Assistente                 Marketing      Graduação    3480.990000         226.100000        34.48          -1
# 875        876   Funcionário 876      Masculino    Marketing     Analista        Comunicação Social      Tecnólogo    2501.070000         182.100000      -248.02          -1
# 900        901   Funcionário 901  Não Informado    Marketing     Analista  Publicidade e Propaganda      Graduação     751.980000         164.500000      -248.02          -1
# 918        919   Funcionário 919      Masculino           RH      Gerente                Psicologia      Graduação    7844.270000         132.400000      -248.02          -1
# 929        930   Funcionário 930  Não Informado           RH   Assistente          Recursos Humanos   Ensino Médio    4436.060000         125.300000      -248.02          -1
# 941        942   Funcionário 942       Feminino    Marketing   Assistente  Publicidade e Propaganda      Graduação    2589.020000         154.300000      -248.02          -1
# 962        963   Funcionário 963       Feminino           RH     Analista          Recursos Humanos      Tecnólogo    6641.250000         144.400000      -248.02          -1
# 970        971   Funcionário 971  Não Informado    Marketing     Analista  Publicidade e Propaganda   Ensino Médio    3481.310000         216.000000       569.40          -1
# 989        990   Funcionário 990       Feminino           TI   Assistente    Sistemas de Informação      Graduação    4809.400000         108.500000       209.27          -1
# 999       1000  Funcionário 1000      Masculino    Marketing   Assistente                 Marketing      Graduação    4549.990000         132.400000      -248.02          -1
#
# Total de outliers: 37 (3.70%)

# %%
# Remover os outliers
try:
    dataset = dataset[dataset['is_outlier'] == 1].drop(columns=['is_outlier'])
except Exception as e:
    print(f"Ocorreu um erro: {e}")

# Exibir o dataset sem os outliers
print("Dataset sem os outliers:")
print(dataset.to_string())

# Exibir informações gerais do dataset
print("\nInformações Gerais do Dataset:")
print(dataset.info())
# Out:
# Dataset sem os outliers:
#      Matricula             Nome         Genero Departamento        Cargo                  Formacao   Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 0            1    Funcionário 1       Feminino    Operações      Diretor    Engenharia de Produção  Pós-graduação    5599.508789         139.900000       315.92
# 1            2    Funcionário 2       Feminino   Financeiro     Analista             Administração  Pós-graduação    5128.930000         117.100000       467.94
# 3            4    Funcionário 4  Não Informado    Marketing  Coordenador                 Marketing      Tecnólogo    5844.480000         155.900000       199.47
# 4            5    Funcionário 5  Não Informado    Marketing      Gerente        Comunicação Social      Graduação    3207.520000         151.000000       318.89
# 5            6    Funcionário 6      Masculino           RH      Diretor                Psicologia       Mestrado    4249.390000         156.000000       553.01
# 6            7    Funcionário 7  Não Informado    Marketing      Diretor        Comunicação Social   Ensino Médio    5379.210000         188.400000       725.94
# 7            8    Funcionário 8       Feminino           TI      Diretor  Engenharia da Computação  Pós-graduação    4387.980000         140.700000       569.80
# 8            9    Funcionário 9      Masculino    Operações   Assistente    Engenharia de Produção   Ensino Médio    7661.990000         173.600000       494.84
# 9           10   Funcionário 10      Masculino   Financeiro  Coordenador                  Economia  Pós-graduação    4410.270000         151.500000       187.52
# 10          11   Funcionário 11  Não Informado   Financeiro      Diretor             Administração      Tecnólogo    4756.670000         148.100000       376.53
# 11          12   Funcionário 12  Não Informado    Operações  Coordenador                 Logística      Graduação    6154.150000         171.300000      -248.02
# 12          13   Funcionário 13  Não Informado           TI      Gerente  Engenharia da Computação       Mestrado    5495.800000         179.800000       716.19
# 13          14   Funcionário 14      Masculino           RH   Assistente          Recursos Humanos       Mestrado    4782.090000         149.700000       677.88
# 14          15   Funcionário 15  Não Informado   Financeiro     Analista             Administração      Graduação    3865.260000         144.600000       527.61
# 15          16   Funcionário 16  Não Informado           RH      Gerente             Administração       Mestrado    5452.270000         136.600000       740.92
# 17          18   Funcionário 18  Não Informado   Financeiro      Diretor             Administração       Mestrado    5718.640000         148.500000       381.23
# 18          19   Funcionário 19  Não Informado    Marketing   Assistente             Administração      Tecnólogo    3832.720000         123.000000       347.38
# 20          21   Funcionário 21      Masculino    Marketing      Gerente                 Marketing  Pós-graduação    5599.508789         132.600000       547.09
# 21          22   Funcionário 22       Feminino   Financeiro   Assistente             Administração       Mestrado    2625.970000         175.600000       522.46
# 22          23   Funcionário 23       Feminino    Marketing      Gerente                 Marketing      Tecnólogo    6440.840000         163.700000       578.47
# 23          24   Funcionário 24       Feminino   Financeiro      Diretor             Administração       Mestrado    5338.760000         165.800000       369.10
# 24          25   Funcionário 25      Masculino           TI      Gerente    Sistemas de Informação  Pós-graduação    4175.750000         148.300000       293.04
# 25          26   Funcionário 26  Não Informado    Marketing      Diretor  Publicidade e Propaganda      Graduação    3352.140000         167.300000       344.57
# 26          27   Funcionário 27  Não Informado   Financeiro     Analista             Administração  Pós-graduação    5599.508789         126.600000       749.19
# 27          28   Funcionário 28  Não Informado           RH   Assistente             Administração   Ensino Médio    5175.640000         171.800000       212.67
# 28          29   Funcionário 29       Feminino    Marketing  Coordenador        Comunicação Social      Graduação    5801.300000         191.100000       599.73
# 29          30   Funcionário 30      Masculino    Marketing   Assistente  Publicidade e Propaganda      Tecnólogo    5476.830000         177.700000       388.46
# 30          31   Funcionário 31       Feminino    Marketing  Coordenador             Administração      Tecnólogo    5652.210000         119.600000       429.33
# 31          32   Funcionário 32       Feminino   Financeiro   Assistente             Administração   Ensino Médio    5810.140000         140.300000       648.59
# 32          33   Funcionário 33       Feminino           RH      Gerente          Recursos Humanos   Ensino Médio    6098.640000         156.200000       668.80
# 33          34   Funcionário 34  Não Informado           RH      Diretor          Recursos Humanos       Mestrado    4437.170000         169.700000       568.60
# 34          35   Funcionário 35  Não Informado           RH      Diretor          Recursos Humanos   Ensino Médio    4562.540000         175.209222       125.38
# 35          36   Funcionário 36  Não Informado   Financeiro      Diretor             Contabilidade      Graduação    2388.470000         150.100000       814.19
# 36          37   Funcionário 37       Feminino           TI     Analista  Engenharia da Computação   Ensino Médio    3829.540000         171.900000      -248.02
# 37          38   Funcionário 38       Feminino    Operações     Analista             Administração  Pós-graduação    5406.670000         183.300000       518.29
# 38          39   Funcionário 39      Masculino    Marketing  Coordenador        Comunicação Social      Graduação    5599.508789         155.400000       502.05
# 39          40   Funcionário 40  Não Informado    Marketing   Assistente                 Marketing  Pós-graduação    5599.508789         174.600000       860.29
# 40          41   Funcionário 41       Feminino           TI   Assistente    Sistemas de Informação      Graduação    4488.960000         108.400000       689.44
# 41          42   Funcionário 42      Masculino    Operações      Gerente             Administração   Ensino Médio    3105.240000         175.209222       494.14
# 43          44   Funcionário 44       Feminino   Financeiro     Analista             Contabilidade      Graduação    6727.600000         150.200000       461.29
# 44          45   Funcionário 45       Feminino   Financeiro     Analista             Contabilidade   Ensino Médio    4116.160000         175.209222      -248.02
# 45          46   Funcionário 46      Masculino    Operações      Diretor    Engenharia de Produção      Tecnólogo    4327.300000         175.209222       708.00
# 46          47   Funcionário 47      Masculino   Financeiro  Coordenador             Contabilidade      Tecnólogo    5197.360000         170.100000      -248.02
# 47          48   Funcionário 48      Masculino    Operações  Coordenador             Administração      Tecnólogo    2891.660000         147.600000      -248.02
# 48          49   Funcionário 49  Não Informado           RH     Analista          Recursos Humanos      Graduação    4475.330000         129.500000       672.82
# 49          50   Funcionário 50      Masculino    Operações  Coordenador    Engenharia de Produção   Ensino Médio    8035.210000         171.100000       198.71
# 51          52   Funcionário 52       Feminino    Marketing      Diretor             Administração      Tecnólogo    5538.870000         175.209222       144.59
# 52          53   Funcionário 53  Não Informado           TI     Analista    Sistemas de Informação      Tecnólogo    5599.508789         175.209222       525.90
# 54          55   Funcionário 55  Não Informado           RH  Coordenador          Recursos Humanos       Mestrado    2865.810000         165.700000       363.65
# 55          56   Funcionário 56      Masculino           RH  Coordenador          Recursos Humanos       Mestrado    7883.490000         159.900000       377.79
# 56          57   Funcionário 57       Feminino           RH   Assistente          Recursos Humanos      Graduação    1827.420000         159.300000       358.23
# 57          58   Funcionário 58      Masculino           RH  Coordenador          Recursos Humanos      Graduação    7108.050000         158.300000       790.31
# 58          59   Funcionário 59      Masculino    Marketing   Assistente                 Marketing   Ensino Médio    7427.080000         168.400000       607.10
# 59          60   Funcionário 60  Não Informado    Marketing      Gerente  Publicidade e Propaganda      Graduação    3763.390000         178.500000       420.09
# 60          61   Funcionário 61      Masculino           TI     Analista    Sistemas de Informação      Tecnólogo    5633.870000         169.900000       313.38
# 61          62   Funcionário 62      Masculino    Marketing  Coordenador             Administração       Mestrado    5821.220000         180.200000       452.24
# 62          63   Funcionário 63  Não Informado   Financeiro      Gerente                  Economia       Mestrado    3779.310000         159.100000       294.18
# 63          64   Funcionário 64  Não Informado    Marketing  Coordenador        Comunicação Social   Ensino Médio    2826.320000         192.400000       694.62
# 64          65   Funcionário 65      Masculino    Operações     Analista             Administração   Ensino Médio    3023.420000         171.400000       899.35
# 65          66   Funcionário 66      Masculino    Marketing   Assistente             Administração      Graduação    5811.510000         149.100000       710.64
# 66          67   Funcionário 67  Não Informado           TI      Diretor    Sistemas de Informação   Ensino Médio    4872.330000         138.100000       566.34
# 67          68   Funcionário 68       Feminino    Operações     Analista                 Logística   Ensino Médio    4153.550000         164.100000       466.87
# 68          69   Funcionário 69  Não Informado    Marketing     Analista                 Marketing      Tecnólogo    6450.150000         133.900000       418.98
# 69          70   Funcionário 70  Não Informado    Operações      Gerente             Administração      Graduação    5762.100000         140.500000       849.06
# 70          71   Funcionário 71      Masculino    Marketing   Assistente             Administração  Pós-graduação    3866.810000         164.800000      -248.02
# 71          72   Funcionário 72  Não Informado    Marketing      Gerente             Administração      Tecnólogo    3198.200000         147.800000       812.22
# 72          73   Funcionário 73  Não Informado    Marketing   Assistente                 Marketing  Pós-graduação    5784.890000         175.209222       273.69
# 73          74   Funcionário 74       Feminino    Operações      Gerente             Administração      Graduação    4193.620000         159.300000       440.75
# 74          75   Funcionário 75      Masculino    Operações     Analista    Engenharia de Produção      Graduação    5148.810000         161.500000       157.19
# 75          76   Funcionário 76      Masculino    Operações      Gerente    Engenharia de Produção       Mestrado    5599.508789         155.900000       531.85
# 76          77   Funcionário 77       Feminino   Financeiro  Coordenador             Contabilidade       Mestrado    5753.490000         152.400000       247.25
# 77          78   Funcionário 78  Não Informado    Operações   Assistente             Administração   Ensino Médio    3706.600000         177.100000       833.01
# 78          79   Funcionário 79       Feminino    Marketing      Diretor        Comunicação Social  Pós-graduação    5240.990000         166.800000       582.45
# 79          80   Funcionário 80  Não Informado           TI  Coordenador    Sistemas de Informação   Ensino Médio    3571.030000         155.500000       607.48
# 80          81   Funcionário 81  Não Informado   Financeiro      Diretor                  Economia      Graduação    7412.780000         175.209222       556.54
# 81          82   Funcionário 82       Feminino           RH  Coordenador                Psicologia      Graduação    4157.630000         163.900000       281.49
# 82          83   Funcionário 83      Masculino           RH   Assistente          Recursos Humanos   Ensino Médio    5310.910000         182.600000       524.82
# 83          84   Funcionário 84      Masculino    Marketing   Assistente  Publicidade e Propaganda  Pós-graduação    5461.600000         148.800000       867.42
# 84          85   Funcionário 85  Não Informado   Financeiro     Analista             Administração      Graduação    5238.880000         132.700000       501.71
# 85          86   Funcionário 86      Masculino   Financeiro      Diretor             Contabilidade       Mestrado    2062.180000         144.200000       296.60
# 86          87   Funcionário 87       Feminino           RH      Diretor          Recursos Humanos       Mestrado    2830.370000         154.600000      -248.02
# 87          88   Funcionário 88       Feminino           TI     Analista    Sistemas de Informação       Mestrado    4321.470000         150.100000       357.33
# 88          89   Funcionário 89       Feminino    Operações     Analista    Engenharia de Produção      Tecnólogo    5479.150000         186.700000       147.55
# 89          90   Funcionário 90       Feminino           TI      Gerente     Ciência da Computação      Graduação    4793.330000         157.600000       666.10
# 90          91   Funcionário 91       Feminino   Financeiro      Diretor             Contabilidade   Ensino Médio    5599.508789         169.200000       656.23
# 91          92   Funcionário 92      Masculino    Marketing   Assistente        Comunicação Social      Graduação    2977.360000         159.100000       324.86
# 92          93   Funcionário 93  Não Informado           TI      Diretor  Engenharia da Computação      Graduação    4397.660000         151.300000       622.80
# 93          94   Funcionário 94       Feminino           TI      Gerente     Ciência da Computação   Ensino Médio    4297.290000         160.800000       384.71
# 94          95   Funcionário 95  Não Informado   Financeiro   Assistente             Administração      Tecnólogo    5769.250000         194.300000       490.88
# 95          96   Funcionário 96  Não Informado           RH   Assistente             Administração      Graduação    4510.520000         144.600000      -248.02
# 96          97   Funcionário 97       Feminino   Financeiro  Coordenador                  Economia      Graduação    5599.508789         175.300000       411.21
# 97          98   Funcionário 98  Não Informado           TI     Analista    Sistemas de Informação      Graduação    4108.030000         175.209222       583.64
# 98          99   Funcionário 99      Masculino           TI   Assistente  Engenharia da Computação      Graduação    4616.060000         150.800000       162.85
# 99         100  Funcionário 100  Não Informado    Marketing   Assistente  Publicidade e Propaganda      Tecnólogo    4477.930000         160.100000       523.49
# 100        101  Funcionário 101  Não Informado           TI      Gerente  Engenharia da Computação   Ensino Médio    3826.450000         166.500000       493.01
# 101        102  Funcionário 102       Feminino    Marketing   Assistente  Publicidade e Propaganda      Tecnólogo    5599.508789         189.700000        90.72
# 102        103  Funcionário 103      Masculino           TI     Analista    Sistemas de Informação   Ensino Médio    3779.610000         159.000000      -248.02
# 103        104  Funcionário 104       Feminino           RH   Assistente             Administração   Ensino Médio    4217.540000         143.100000       128.10
# 104        105  Funcionário 105       Feminino           TI     Analista  Engenharia da Computação      Tecnólogo    5599.508789         173.000000       582.86
# 105        106  Funcionário 106      Masculino    Marketing     Analista                 Marketing   Ensino Médio    3053.930000         152.700000       524.79
# 106        107  Funcionário 107       Feminino    Marketing     Analista             Administração  Pós-graduação    4512.600000         164.800000       554.79
# 107        108  Funcionário 108  Não Informado    Marketing   Assistente             Administração   Ensino Médio    3933.040000         157.700000       234.72
# 109        110  Funcionário 110      Masculino    Marketing      Gerente        Comunicação Social      Graduação    4910.110000         170.200000       696.57
# 110        111  Funcionário 111       Feminino    Operações   Assistente                 Logística      Graduação    3800.130000         171.700000       346.61
# 111        112  Funcionário 112      Masculino           RH   Assistente          Recursos Humanos  Pós-graduação    4669.890000         178.500000       735.21
# 112        113  Funcionário 113       Feminino           TI   Assistente    Sistemas de Informação      Tecnólogo    6963.000000         175.209222      -248.02
# 113        114  Funcionário 114  Não Informado    Marketing      Gerente        Comunicação Social      Tecnólogo    4961.300000         136.100000       144.76
# 114        115  Funcionário 115       Feminino           RH   Assistente             Administração  Pós-graduação    6717.890000         170.300000      -248.02
# 115        116  Funcionário 116       Feminino           TI   Assistente  Engenharia da Computação   Ensino Médio    5519.740000         168.200000       646.74
# 116        117  Funcionário 117      Masculino           RH  Coordenador             Administração   Ensino Médio    6161.240000         151.600000       479.19
# 117        118  Funcionário 118      Masculino    Operações     Analista    Engenharia de Produção  Pós-graduação    3838.310000         175.209222       676.24
# 118        119  Funcionário 119       Feminino           TI   Assistente  Engenharia da Computação   Ensino Médio    5599.508789         170.000000       482.33
# 119        120  Funcionário 120  Não Informado    Marketing      Gerente        Comunicação Social   Ensino Médio    5200.870000         135.600000       553.53
# 120        121  Funcionário 121       Feminino   Financeiro     Analista             Contabilidade      Graduação    4081.060000         175.209222       924.71
# 121        122  Funcionário 122  Não Informado    Marketing  Coordenador  Publicidade e Propaganda   Ensino Médio    3765.760000         141.600000       779.37
# 122        123  Funcionário 123       Feminino           TI     Analista     Ciência da Computação      Tecnólogo    2764.600000         147.000000       413.43
# 123        124  Funcionário 124      Masculino    Marketing  Coordenador        Comunicação Social  Pós-graduação    7244.210000         124.500000       574.99
# 124        125  Funcionário 125  Não Informado   Financeiro      Gerente             Contabilidade      Graduação    3541.400000         150.500000       598.89
# 125        126  Funcionário 126       Feminino   Financeiro   Assistente             Contabilidade      Graduação    7019.330000         155.900000       652.28
# 126        127  Funcionário 127  Não Informado   Financeiro   Assistente             Contabilidade      Graduação    4298.760000         171.000000       514.20
# 127        128  Funcionário 128  Não Informado    Marketing     Analista             Administração  Pós-graduação    3706.260000         160.000000       401.29
# 128        129  Funcionário 129       Feminino           TI      Gerente     Ciência da Computação      Tecnólogo    5599.508789         129.200000       499.28
# 129        130  Funcionário 130  Não Informado    Marketing   Assistente        Comunicação Social  Pós-graduação    4053.210000         175.209222       403.94
# 130        131  Funcionário 131       Feminino   Financeiro   Assistente             Administração      Tecnólogo    5852.690000         175.209222       836.67
# 131        132  Funcionário 132       Feminino    Operações   Assistente             Administração      Tecnólogo    4500.780000         169.800000       748.15
# 132        133  Funcionário 133  Não Informado   Financeiro   Assistente             Administração   Ensino Médio    5599.508789         179.300000       459.28
# 133        134  Funcionário 134       Feminino   Financeiro      Gerente             Contabilidade      Graduação    5599.508789         188.500000      -248.02
# 134        135  Funcionário 135      Masculino           TI   Assistente     Ciência da Computação      Tecnólogo    6247.030000         199.200000       466.91
# 135        136  Funcionário 136  Não Informado    Marketing      Gerente                 Marketing   Ensino Médio    5731.960000         158.600000       738.65
# 136        137  Funcionário 137      Masculino           TI     Analista    Sistemas de Informação      Graduação    3620.520000         166.200000      -248.02
# 137        138  Funcionário 138      Masculino    Marketing   Assistente  Publicidade e Propaganda  Pós-graduação    8964.400000         138.400000       613.72
# 138        139  Funcionário 139      Masculino   Financeiro  Coordenador                  Economia      Graduação    5810.180000         181.200000       674.25
# 139        140  Funcionário 140      Masculino   Financeiro   Assistente                  Economia      Tecnólogo    8435.700000         136.300000       632.11
# 140        141  Funcionário 141      Masculino   Financeiro   Assistente                  Economia      Graduação    7400.400000         123.900000       734.81
# 141        142  Funcionário 142      Masculino    Marketing   Assistente  Publicidade e Propaganda   Ensino Médio    4716.750000         175.209222       606.23
# 142        143  Funcionário 143       Feminino   Financeiro      Gerente             Contabilidade      Graduação    4381.590000         175.209222       530.38
# 143        144  Funcionário 144       Feminino           TI      Gerente  Engenharia da Computação      Graduação    4394.810000         175.600000       384.55
# 144        145  Funcionário 145  Não Informado           TI     Analista    Sistemas de Informação  Pós-graduação    2254.960000         175.209222       185.65
# 145        146  Funcionário 146      Masculino   Financeiro  Coordenador             Contabilidade      Graduação    5599.508789         175.209222      -248.02
# 146        147  Funcionário 147       Feminino    Operações     Analista    Engenharia de Produção      Graduação    5370.150000         105.600000       351.79
# 147        148  Funcionário 148      Masculino    Marketing  Coordenador                 Marketing      Tecnólogo    5599.508789         138.100000       512.00
# 148        149  Funcionário 149  Não Informado    Operações     Analista                 Logística  Pós-graduação    3840.840000         160.300000       728.10
# 149        150  Funcionário 150       Feminino   Financeiro     Analista                  Economia      Graduação    5599.508789         135.600000       534.56
# 150        151  Funcionário 151       Feminino    Operações   Assistente                 Logística   Ensino Médio    3121.110000         146.900000       417.00
# 151        152  Funcionário 152       Feminino    Marketing   Assistente        Comunicação Social      Graduação    4120.520000         130.800000       329.37
# 152        153  Funcionário 153      Masculino    Marketing      Gerente                 Marketing      Graduação    5599.508789         163.400000       213.97
# 153        154  Funcionário 154      Masculino    Operações     Analista             Administração   Ensino Médio    5557.720000         161.800000       766.56
# 154        155  Funcionário 155       Feminino           RH   Assistente             Administração   Ensino Médio    5599.508789         150.400000      -248.02
# 155        156  Funcionário 156      Masculino    Marketing   Assistente                 Marketing  Pós-graduação    6443.510000         175.209222       313.04
# 156        157  Funcionário 157  Não Informado   Financeiro   Assistente             Administração      Graduação    6156.260000         190.000000        37.36
# 157        158  Funcionário 158       Feminino   Financeiro   Assistente             Contabilidade      Graduação    5364.750000         171.300000       436.77
# 158        159  Funcionário 159       Feminino    Marketing     Analista             Administração      Tecnólogo    5585.550000         124.000000      -248.02
# 159        160  Funcionário 160      Masculino           RH     Analista          Recursos Humanos      Tecnólogo    5599.508789         137.900000       419.14
# 160        161  Funcionário 161      Masculino   Financeiro   Assistente                  Economia      Graduação    4233.610000         168.100000       487.37
# 161        162  Funcionário 162  Não Informado    Operações   Assistente                 Logística  Pós-graduação    6162.090000         147.400000       335.75
# 162        163  Funcionário 163       Feminino           RH      Gerente             Administração      Tecnólogo    2287.780000         150.300000       317.27
# 163        164  Funcionário 164  Não Informado    Marketing     Analista                 Marketing      Graduação    5617.000000         178.000000       863.57
# 164        165  Funcionário 165  Não Informado           RH     Analista                Psicologia  Pós-graduação    5599.508789         170.200000       433.19
# 165        166  Funcionário 166       Feminino   Financeiro   Assistente                  Economia  Pós-graduação    5003.860000         186.300000       681.53
# 166        167  Funcionário 167  Não Informado   Financeiro   Assistente                  Economia      Graduação    6560.130000         151.400000       332.65
# 167        168  Funcionário 168       Feminino    Operações     Analista             Administração  Pós-graduação    5246.970000         187.500000       822.55
# 168        169  Funcionário 169      Masculino    Marketing   Assistente        Comunicação Social      Graduação    6327.780000         148.900000       802.84
# 169        170  Funcionário 170       Feminino    Marketing      Gerente                 Marketing      Tecnólogo    7210.650000         190.000000       546.20
# 170        171  Funcionário 171      Masculino           RH     Analista                Psicologia      Tecnólogo    5583.640000         162.100000       280.09
# 171        172  Funcionário 172      Masculino   Financeiro     Analista                  Economia  Pós-graduação    6756.560000         142.800000       517.40
# 172        173  Funcionário 173      Masculino   Financeiro  Coordenador             Contabilidade  Pós-graduação    4510.160000         127.400000       509.46
# 173        174  Funcionário 174  Não Informado           RH  Coordenador          Recursos Humanos      Graduação    4987.690000         154.000000       547.92
# 175        176  Funcionário 176      Masculino   Financeiro   Assistente                  Economia      Graduação    6564.470000         177.200000       195.40
# 176        177  Funcionário 177  Não Informado    Marketing      Gerente        Comunicação Social  Pós-graduação    5599.508789         157.800000       532.47
# 177        178  Funcionário 178  Não Informado           RH   Assistente                Psicologia   Ensino Médio    5599.508789         151.400000       497.94
# 178        179  Funcionário 179       Feminino    Marketing     Analista             Administração   Ensino Médio    5232.000000         181.500000      -248.02
# 179        180  Funcionário 180       Feminino    Operações     Analista             Administração  Pós-graduação    6562.350000         155.500000       705.36
# 180        181  Funcionário 181      Masculino   Financeiro   Assistente             Administração      Graduação    5599.508789         175.209222       204.97
# 181        182  Funcionário 182       Feminino   Financeiro     Analista             Contabilidade   Ensino Médio    3576.600000         171.500000       702.14
# 182        183  Funcionário 183      Masculino    Marketing     Analista  Publicidade e Propaganda      Graduação    5197.870000         150.200000       351.35
# 183        184  Funcionário 184  Não Informado           TI     Analista     Ciência da Computação      Tecnólogo    2029.150000         173.200000       420.96
# 184        185  Funcionário 185  Não Informado    Marketing   Assistente             Administração  Pós-graduação    6153.160000         148.100000       334.84
# 185        186  Funcionário 186      Masculino           TI      Gerente    Sistemas de Informação   Ensino Médio    4368.010000         155.500000       517.92
# 186        187  Funcionário 187  Não Informado    Operações     Analista    Engenharia de Produção      Tecnólogo    4296.030000         163.000000       118.84
# 187        188  Funcionário 188       Feminino    Marketing   Assistente             Administração      Graduação    6313.540000         152.500000       386.38
# 188        189  Funcionário 189       Feminino    Marketing   Assistente        Comunicação Social      Graduação    2952.260000         159.700000       396.85
# 189        190  Funcionário 190      Masculino   Financeiro   Assistente                  Economia      Tecnólogo    7920.650000         176.300000       752.79
# 190        191  Funcionário 191       Feminino    Marketing     Analista        Comunicação Social  Pós-graduação    4279.640000         168.200000       530.14
# 191        192  Funcionário 192       Feminino    Marketing   Assistente             Administração      Tecnólogo    4215.120000         169.600000       639.10
# 192        193  Funcionário 193  Não Informado    Operações     Analista    Engenharia de Produção  Pós-graduação    6531.840000         147.300000       501.19
# 193        194  Funcionário 194      Masculino           TI      Gerente    Sistemas de Informação      Graduação    6063.040000         177.100000       290.22
# 194        195  Funcionário 195      Masculino    Marketing   Assistente                 Marketing   Ensino Médio    8676.840000         173.400000       681.44
# 195        196  Funcionário 196  Não Informado    Operações     Analista             Administração      Graduação    5599.508789         180.100000       330.91
# 196        197  Funcionário 197      Masculino   Financeiro   Assistente                  Economia  Pós-graduação    4819.390000         145.500000       394.75
# 197        198  Funcionário 198  Não Informado           TI   Assistente     Ciência da Computação      Tecnólogo    2781.030000         175.209222       536.42
# 198        199  Funcionário 199      Masculino    Marketing     Analista                 Marketing      Graduação    4501.850000         175.209222       689.11
# 199        200  Funcionário 200      Masculino    Marketing  Coordenador  Publicidade e Propaganda   Ensino Médio    3917.850000         147.800000       459.72
# 200        201  Funcionário 201      Masculino           RH      Gerente                Psicologia   Ensino Médio    4326.850000         175.209222      -248.02
# 201        202  Funcionário 202  Não Informado    Marketing     Analista                 Marketing      Tecnólogo    2383.720000         198.500000       385.70
# 202        203  Funcionário 203  Não Informado    Operações     Analista                 Logística      Graduação    7490.910000         199.000000       633.12
# 203        204  Funcionário 204  Não Informado    Marketing   Assistente                 Marketing   Ensino Médio    2875.090000         184.800000       500.72
# 205        206  Funcionário 206      Masculino           RH   Assistente                Psicologia      Tecnólogo    3217.360000         175.209222       542.88
# 206        207  Funcionário 207       Feminino           RH     Analista             Administração  Pós-graduação    4094.240000         170.300000       124.54
# 207        208  Funcionário 208       Feminino           RH     Analista          Recursos Humanos  Pós-graduação    3275.670000         152.800000       717.67
# 208        209  Funcionário 209      Masculino    Marketing     Analista                 Marketing      Graduação    6647.460000         138.800000       483.69
# 209        210  Funcionário 210  Não Informado           TI   Assistente    Sistemas de Informação  Pós-graduação    4793.240000         149.800000       389.39
# 210        211  Funcionário 211      Masculino           TI  Coordenador    Sistemas de Informação   Ensino Médio    5038.080000         175.209222       744.59
# 211        212  Funcionário 212       Feminino    Operações     Analista    Engenharia de Produção      Tecnólogo    5915.590000         149.100000      -248.02
# 212        213  Funcionário 213  Não Informado    Marketing      Gerente                 Marketing   Ensino Médio    5429.020000         175.209222       620.00
# 213        214  Funcionário 214      Masculino           RH   Assistente          Recursos Humanos      Graduação    6467.850000         175.800000       346.32
# 214        215  Funcionário 215      Masculino           TI      Gerente    Sistemas de Informação  Pós-graduação    3335.780000         162.900000       332.77
# 215        216  Funcionário 216      Masculino    Marketing  Coordenador  Publicidade e Propaganda      Tecnólogo    4178.720000         164.700000       862.12
# 216        217  Funcionário 217      Masculino           RH   Assistente             Administração      Tecnólogo    5998.950000         162.200000       342.59
# 217        218  Funcionário 218  Não Informado    Operações     Analista    Engenharia de Produção      Graduação    1198.170000         146.500000       383.05
# 218        219  Funcionário 219  Não Informado           TI     Analista  Engenharia da Computação      Graduação    2937.220000         132.600000       158.34
# 219        220  Funcionário 220  Não Informado           TI     Analista     Ciência da Computação      Tecnólogo    5751.490000         166.200000       826.00
# 220        221  Funcionário 221  Não Informado    Marketing  Coordenador             Administração  Pós-graduação    4279.630000         149.900000       579.60
# 221        222  Funcionário 222  Não Informado           RH   Assistente             Administração      Graduação    6404.160000         119.800000       547.56
# 222        223  Funcionário 223  Não Informado   Financeiro      Gerente             Contabilidade      Graduação    6213.770000         152.100000       695.03
# 223        224  Funcionário 224       Feminino    Operações     Analista             Administração   Ensino Médio    3202.860000         138.200000       234.13
# 224        225  Funcionário 225       Feminino   Financeiro     Analista             Administração   Ensino Médio    5609.990000         174.000000       391.79
# 225        226  Funcionário 226  Não Informado    Marketing   Assistente        Comunicação Social      Graduação    6802.550000         170.400000       481.71
# 226        227  Funcionário 227  Não Informado           TI     Analista     Ciência da Computação   Ensino Médio    5221.150000         169.900000       190.31
# 227        228  Funcionário 228  Não Informado   Financeiro   Assistente             Administração      Tecnólogo    3533.800000         146.700000       762.29
# 228        229  Funcionário 229       Feminino    Marketing     Analista             Administração      Tecnólogo    6319.080000         174.600000       496.31
# 229        230  Funcionário 230  Não Informado           RH     Analista             Administração   Ensino Médio    5953.140000         166.400000       435.34
# 230        231  Funcionário 231  Não Informado           RH   Assistente          Recursos Humanos      Tecnólogo    5813.920000         151.800000       547.25
# 231        232  Funcionário 232       Feminino   Financeiro     Analista                  Economia      Graduação    6073.910000         175.209222       349.48
# 233        234  Funcionário 234      Masculino    Marketing  Coordenador             Administração      Tecnólogo    6321.410000         150.500000      1185.51
# 234        235  Funcionário 235       Feminino    Marketing     Analista        Comunicação Social      Graduação    7712.200000         166.100000       620.94
# 235        236  Funcionário 236       Feminino   Financeiro   Assistente                  Economia      Graduação    5654.960000         180.700000       833.66
# 236        237  Funcionário 237       Feminino    Operações   Assistente             Administração      Tecnólogo    5289.090000         198.200000       428.98
# 237        238  Funcionário 238       Feminino    Operações     Analista    Engenharia de Produção      Graduação    6044.660000         193.300000       349.69
# 238        239  Funcionário 239       Feminino   Financeiro   Assistente                  Economia  Pós-graduação    5507.340000         178.000000       561.94
# 239        240  Funcionário 240       Feminino           RH     Analista                Psicologia   Ensino Médio    5599.508789         129.900000       231.66
# 240        241  Funcionário 241       Feminino    Marketing      Gerente                 Marketing      Graduação    5002.210000         146.200000        38.61
# 241        242  Funcionário 242       Feminino    Operações   Assistente    Engenharia de Produção      Graduação    3849.940000         149.000000       646.32
# 242        243  Funcionário 243       Feminino    Marketing     Analista                 Marketing      Graduação    3493.520000         193.100000       628.27
# 243        244  Funcionário 244  Não Informado           TI      Gerente  Engenharia da Computação   Ensino Médio    3502.710000         146.000000       666.77
# 244        245  Funcionário 245      Masculino           RH     Analista          Recursos Humanos  Pós-graduação    2940.440000         167.700000      -248.02
# 245        246  Funcionário 246      Masculino    Marketing   Assistente             Administração      Graduação    3398.390000         162.000000       895.67
# 246        247  Funcionário 247      Masculino           TI   Assistente    Sistemas de Informação      Tecnólogo    5599.508789         141.300000       482.53
# 247        248  Funcionário 248  Não Informado           RH      Gerente             Administração      Graduação    6131.140000         167.600000      -248.02
# 248        249  Funcionário 249      Masculino    Operações   Assistente                 Logística      Graduação    4062.460000         168.000000      -101.30
# 249        250  Funcionário 250       Feminino           TI   Assistente     Ciência da Computação      Graduação    4414.410000         134.900000       490.57
# 251        252  Funcionário 252  Não Informado    Operações     Analista             Administração  Pós-graduação    4016.680000         118.300000       501.37
# 252        253  Funcionário 253       Feminino    Marketing     Analista             Administração      Tecnólogo    5101.280000         148.200000       724.84
# 253        254  Funcionário 254  Não Informado    Marketing     Analista        Comunicação Social   Ensino Médio    6166.410000         179.400000       958.98
# 254        255  Funcionário 255       Feminino    Marketing   Assistente        Comunicação Social      Tecnólogo    4946.390000         136.100000       465.33
# 255        256  Funcionário 256       Feminino           RH  Coordenador                Psicologia   Ensino Médio    5504.020000         167.000000       746.25
# 256        257  Funcionário 257  Não Informado           TI   Assistente     Ciência da Computação  Pós-graduação    6329.740000         134.100000       182.83
# 257        258  Funcionário 258  Não Informado    Operações   Assistente                 Logística      Tecnólogo    4591.800000         158.100000       706.26
# 258        259  Funcionário 259       Feminino    Marketing     Analista                 Marketing   Ensino Médio    5427.190000         175.209222       512.70
# 259        260  Funcionário 260      Masculino    Marketing     Analista             Administração      Graduação    4535.930000         143.100000       455.72
# 260        261  Funcionário 261       Feminino           RH     Analista          Recursos Humanos      Graduação    4957.210000         129.100000       467.32
# 261        262  Funcionário 262       Feminino           RH   Assistente             Administração      Tecnólogo    4512.900000         152.000000       468.74
# 262        263  Funcionário 263       Feminino           RH      Gerente                Psicologia      Graduação    4206.700000         151.700000       438.24
# 263        264  Funcionário 264  Não Informado           RH   Assistente             Administração      Graduação    5599.508789         146.500000       539.73
# 264        265  Funcionário 265      Masculino           TI   Assistente     Ciência da Computação  Pós-graduação    5849.820000         176.000000      -248.02
# 265        266  Funcionário 266  Não Informado   Financeiro   Assistente                  Economia      Graduação    5219.460000         142.300000       268.84
# 266        267  Funcionário 267      Masculino    Marketing   Assistente        Comunicação Social      Tecnólogo    5748.090000         172.700000       583.41
# 267        268  Funcionário 268      Masculino    Marketing     Analista             Administração      Graduação    3893.100000         192.600000      -248.02
# 268        269  Funcionário 269  Não Informado    Operações  Coordenador             Administração      Graduação    3194.400000         162.800000       709.60
# 269        270  Funcionário 270      Masculino    Marketing   Assistente        Comunicação Social      Graduação    5625.570000         142.800000       493.23
# 270        271  Funcionário 271  Não Informado           RH   Assistente                Psicologia      Tecnólogo    6031.820000         135.000000       525.40
# 271        272  Funcionário 272      Masculino           RH   Assistente                Psicologia      Graduação    5074.790000         145.800000        90.15
# 272        273  Funcionário 273       Feminino           TI     Analista  Engenharia da Computação   Ensino Médio    5599.508789         174.100000       248.66
# 273        274  Funcionário 274  Não Informado    Marketing   Assistente             Administração   Ensino Médio    6361.550000         163.100000       687.92
# 274        275  Funcionário 275       Feminino   Financeiro   Assistente                  Economia      Graduação    9020.860000         178.700000       353.24
# 275        276  Funcionário 276       Feminino           TI  Coordenador     Ciência da Computação      Graduação    4698.790000         175.400000       393.51
# 276        277  Funcionário 277  Não Informado    Operações     Analista                 Logística  Pós-graduação    3501.730000         162.800000       444.41
# 277        278  Funcionário 278  Não Informado   Financeiro   Assistente             Contabilidade      Tecnólogo    3889.790000         169.500000       772.75
# 278        279  Funcionário 279  Não Informado    Marketing     Analista             Administração      Tecnólogo    4151.750000         197.100000       574.83
# 279        280  Funcionário 280  Não Informado    Marketing     Analista        Comunicação Social      Tecnólogo    5714.050000         188.300000       762.05
# 280        281  Funcionário 281  Não Informado    Marketing   Assistente                 Marketing      Graduação    1762.900000         153.900000       446.45
# 281        282  Funcionário 282  Não Informado   Financeiro  Coordenador                  Economia      Graduação    6977.830000         179.800000       542.64
# 282        283  Funcionário 283      Masculino   Financeiro     Analista                  Economia  Pós-graduação    5599.508789         171.700000       259.35
# 283        284  Funcionário 284  Não Informado    Marketing     Analista        Comunicação Social      Graduação    4629.810000         175.209222       735.61
# 284        285  Funcionário 285  Não Informado    Marketing   Assistente        Comunicação Social      Graduação    3380.990000         173.400000       521.73
# 285        286  Funcionário 286      Masculino    Marketing   Assistente             Administração      Graduação    4828.660000         175.209222       508.83
# 286        287  Funcionário 287       Feminino    Marketing   Assistente        Comunicação Social      Tecnólogo    5019.860000         127.600000       567.66
# 287        288  Funcionário 288  Não Informado    Marketing   Assistente             Administração      Tecnólogo    4817.080000         171.500000       789.36
# 288        289  Funcionário 289       Feminino           TI   Assistente     Ciência da Computação   Ensino Médio    5508.590000         198.100000       457.10
# 289        290  Funcionário 290      Masculino           RH      Gerente             Administração      Tecnólogo    4115.550000         144.500000       832.61
# 290        291  Funcionário 291       Feminino   Financeiro   Assistente                  Economia      Tecnólogo    3656.280000         156.200000       329.70
# 291        292  Funcionário 292       Feminino    Operações   Assistente                 Logística  Pós-graduação    5822.490000         139.300000       584.44
# 292        293  Funcionário 293  Não Informado   Financeiro   Assistente             Administração      Graduação    5148.000000         183.600000       901.84
# 293        294  Funcionário 294       Feminino    Marketing     Analista  Publicidade e Propaganda      Tecnólogo    5295.770000         113.900000       402.04
# 294        295  Funcionário 295      Masculino    Operações  Coordenador                 Logística   Ensino Médio    6588.540000         114.700000       549.05
# 295        296  Funcionário 296       Feminino    Operações     Analista    Engenharia de Produção   Ensino Médio    3466.150000         167.500000       675.50
# 296        297  Funcionário 297  Não Informado           RH      Gerente             Administração      Graduação    3717.140000         158.400000       472.42
# 297        298  Funcionário 298  Não Informado   Financeiro   Assistente                  Economia      Graduação    6885.830000         150.400000       199.93
# 298        299  Funcionário 299       Feminino           TI     Analista  Engenharia da Computação  Pós-graduação    2775.670000         154.000000       288.81
# 299        300  Funcionário 300      Masculino    Operações   Assistente             Administração   Ensino Médio    3035.880000         170.700000       616.19
# 300        301  Funcionário 301  Não Informado    Marketing     Analista             Administração      Graduação    6226.790000         151.700000      -248.02
# 301        302  Funcionário 302      Masculino           TI   Assistente  Engenharia da Computação      Graduação    5357.300000         138.100000       656.91
# 302        303  Funcionário 303  Não Informado    Operações  Coordenador    Engenharia de Produção      Tecnólogo    5157.850000         141.500000      -248.02
# 303        304  Funcionário 304       Feminino    Marketing     Analista             Administração      Tecnólogo    4862.510000         177.800000       514.40
# 304        305  Funcionário 305      Masculino           TI     Analista  Engenharia da Computação      Tecnólogo    5046.900000         149.500000       541.65
# 305        306  Funcionário 306  Não Informado    Marketing   Assistente        Comunicação Social      Tecnólogo    4861.830000         132.300000       196.23
# 306        307  Funcionário 307      Masculino   Financeiro   Assistente             Contabilidade      Graduação    7033.160000         162.000000       563.47
# ...
# 898        899  Funcionário 899  Não Informado    Operações  Coordenador             Administração  Pós-graduação    4904.510000         171.000000       314.43
# 899        900  Funcionário 900      Masculino    Marketing     Analista                 Marketing   Ensino Médio    2630.100000         143.700000       881.32
# 901        902  Funcionário 902  Não Informado           RH     Analista          Recursos Humanos   Ensino Médio    3374.860000         153.400000       464.53
# 902        903  Funcionário 903  Não Informado           TI   Assistente    Sistemas de Informação   Ensino Médio    4804.070000         138.200000      -248.02
# 903        904  Funcionário 904       Feminino    Operações      Gerente                 Logística      Graduação    7101.030000         157.500000        -7.70
# 904        905  Funcionário 905       Feminino   Financeiro   Assistente                  Economia      Tecnólogo    4022.520000         175.209222       702.02
# 905        906  Funcionário 906  Não Informado   Financeiro     Analista             Contabilidade      Tecnólogo    5757.220000         206.300000       517.14
# 906        907  Funcionário 907      Masculino           RH   Assistente                Psicologia      Graduação    6954.770000         162.800000       153.23
# 907        908  Funcionário 908      Masculino    Marketing   Assistente             Administração      Graduação    5599.508789         194.800000       171.88
# 908        909  Funcionário 909  Não Informado           TI   Assistente     Ciência da Computação      Graduação    4786.330000         159.100000       729.07
# 909        910  Funcionário 910       Feminino    Marketing      Gerente        Comunicação Social      Tecnólogo    3036.850000         158.900000       469.88
# 910        911  Funcionário 911  Não Informado    Operações      Gerente                 Logística      Graduação    3196.290000         121.000000       786.29
# 911        912  Funcionário 912      Masculino    Marketing     Analista        Comunicação Social  Pós-graduação    5599.508789         175.209222       627.32
# 912        913  Funcionário 913       Feminino    Marketing  Coordenador             Administração      Graduação    4698.640000         144.300000       486.69
# 913        914  Funcionário 914      Masculino    Marketing   Assistente        Comunicação Social  Pós-graduação    5183.800000         162.200000      -248.02
# 914        915  Funcionário 915      Masculino           TI   Assistente     Ciência da Computação   Ensino Médio    4929.080000         160.300000       388.99
# 915        916  Funcionário 916  Não Informado   Financeiro     Analista             Administração      Graduação    5996.220000         175.209222       519.56
# 916        917  Funcionário 917       Feminino    Operações  Coordenador                 Logística  Pós-graduação    3822.970000         148.200000       487.80
# 917        918  Funcionário 918  Não Informado           TI  Coordenador     Ciência da Computação      Graduação    4496.630000         156.700000       667.50
# 919        920  Funcionário 920       Feminino    Operações   Assistente                 Logística      Graduação    3800.320000         147.700000       664.71
# 920        921  Funcionário 921       Feminino    Marketing      Gerente        Comunicação Social  Pós-graduação    4577.640000         152.400000       684.13
# 921        922  Funcionário 922       Feminino           RH   Assistente             Administração   Ensino Médio    4115.920000         135.000000       536.15
# 922        923  Funcionário 923       Feminino    Marketing     Analista                 Marketing   Ensino Médio    5667.170000         153.400000       237.41
# 923        924  Funcionário 924      Masculino           TI     Analista  Engenharia da Computação   Ensino Médio    6533.590000         143.300000       467.90
# 924        925  Funcionário 925      Masculino           TI   Assistente    Sistemas de Informação  Pós-graduação    4252.680000         184.700000       118.79
# 925        926  Funcionário 926  Não Informado           RH  Coordenador             Administração      Graduação    4352.880000         155.100000       258.68
# 926        927  Funcionário 927  Não Informado   Financeiro      Gerente                  Economia   Ensino Médio    4581.530000         156.200000       646.08
# 927        928  Funcionário 928  Não Informado           RH     Analista          Recursos Humanos   Ensino Médio    5794.750000         168.600000       598.98
# 928        929  Funcionário 929  Não Informado   Financeiro   Assistente             Administração  Pós-graduação    3890.910000         171.100000      -248.02
# 930        931  Funcionário 931  Não Informado           RH   Assistente          Recursos Humanos      Graduação    1441.710000         152.500000       352.12
# 931        932  Funcionário 932  Não Informado    Marketing     Analista             Administração   Ensino Médio    5599.508789         141.800000       397.44
# 932        933  Funcionário 933       Feminino   Financeiro   Assistente             Administração  Pós-graduação    4831.330000         157.100000       693.05
# 933        934  Funcionário 934      Masculino   Financeiro   Assistente                  Economia      Tecnólogo    6346.800000         149.300000       595.34
# 934        935  Funcionário 935  Não Informado    Marketing   Assistente             Administração      Graduação    5442.610000         163.100000       225.76
# 935        936  Funcionário 936      Masculino    Marketing     Analista                 Marketing      Graduação    3351.850000         140.400000       539.77
# 936        937  Funcionário 937  Não Informado           TI   Assistente  Engenharia da Computação      Graduação    2899.620000         148.600000       527.99
# 937        938  Funcionário 938      Masculino   Financeiro   Assistente                  Economia   Ensino Médio    5599.508789         148.200000       829.73
# 938        939  Funcionário 939      Masculino    Operações     Analista             Administração      Tecnólogo    5599.508789         181.700000       148.49
# 939        940  Funcionário 940       Feminino   Financeiro   Assistente                  Economia      Tecnólogo    6598.890000         167.400000       343.37
# 940        941  Funcionário 941       Feminino    Marketing  Coordenador        Comunicação Social      Graduação    5095.840000         167.400000       694.73
# 942        943  Funcionário 943  Não Informado           RH     Analista                Psicologia      Graduação    3551.070000         152.300000       977.12
# 943        944  Funcionário 944  Não Informado    Operações     Analista             Administração  Pós-graduação    5599.508789         171.200000       264.21
# 944        945  Funcionário 945  Não Informado           TI   Assistente  Engenharia da Computação      Tecnólogo    3840.210000         175.500000       505.82
# 945        946  Funcionário 946       Feminino    Operações     Analista    Engenharia de Produção      Graduação    2765.100000         160.300000       611.91
# 946        947  Funcionário 947      Masculino           RH     Analista                Psicologia  Pós-graduação    3688.010000         182.800000       676.21
# 947        948  Funcionário 948      Masculino   Financeiro   Assistente             Contabilidade      Graduação    3973.400000         185.500000       643.04
# 948        949  Funcionário 949      Masculino    Marketing   Assistente  Publicidade e Propaganda      Tecnólogo    3933.070000         126.700000       407.58
# 949        950  Funcionário 950  Não Informado   Financeiro  Coordenador                  Economia      Graduação    6691.930000         168.600000      -248.02
# 950        951  Funcionário 951  Não Informado   Financeiro     Analista             Administração   Ensino Médio    5157.240000         159.100000       349.07
# 951        952  Funcionário 952  Não Informado           RH   Assistente                Psicologia      Doutorado    3510.110000         167.800000       393.00
# 952        953  Funcionário 953      Masculino           TI     Analista  Engenharia da Computação  Pós-graduação    4498.070000         182.300000       591.33
# 953        954  Funcionário 954       Feminino   Financeiro      Gerente             Contabilidade   Ensino Médio    3680.660000         141.600000       801.92
# 954        955  Funcionário 955      Masculino    Marketing      Gerente        Comunicação Social      Doutorado    4549.990000         127.600000       454.37
# 955        956  Funcionário 956       Feminino    Marketing   Assistente                 Marketing  Pós-graduação    6313.260000         182.100000       321.93
# 956        957  Funcionário 957       Feminino    Marketing     Analista             Administração   Ensino Médio    5378.410000         140.000000       741.95
# 957        958  Funcionário 958       Feminino           TI     Analista     Ciência da Computação   Ensino Médio    8428.400000         146.300000       247.04
# 958        959  Funcionário 959  Não Informado           RH   Assistente                Psicologia      Tecnólogo    5563.890000         164.100000       867.64
# 959        960  Funcionário 960      Masculino    Operações   Assistente                 Logística  Pós-graduação    3629.610000         146.300000       303.18
# 960        961  Funcionário 961       Feminino    Marketing     Analista  Publicidade e Propaganda  Pós-graduação    6214.610000         128.200000       628.19
# 961        962  Funcionário 962       Feminino   Financeiro   Assistente             Administração      Doutorado    6619.900000         160.700000       685.34
# 963        964  Funcionário 964  Não Informado           TI     Analista  Engenharia da Computação      Doutorado    3358.640000         172.000000       545.40
# 964        965  Funcionário 965       Feminino   Financeiro  Coordenador             Contabilidade   Ensino Médio    4778.540000         149.900000       509.91
# 965        966  Funcionário 966       Feminino    Operações  Coordenador                 Logística      Graduação    6697.720000         146.200000       169.36
# 966        967  Funcionário 967      Masculino    Marketing     Analista             Administração      Tecnólogo    5599.508789         155.800000       343.84
# 967        968  Funcionário 968  Não Informado    Operações   Assistente             Administração      Tecnólogo    4250.870000         181.000000       644.93
# 968        969  Funcionário 969       Feminino    Marketing     Analista             Administração      Tecnólogo    2859.590000         178.200000       632.67
# 969        970  Funcionário 970      Masculino    Marketing  Coordenador        Comunicação Social      Tecnólogo    3601.140000         138.100000       292.42
# 971        972  Funcionário 972      Masculino    Operações      Gerente             Administração      Graduação    6875.850000         153.500000       550.41
# 972        973  Funcionário 973       Feminino    Marketing   Assistente             Administração  Pós-graduação    4648.190000         137.000000       850.18
# 973        974  Funcionário 974  Não Informado           TI   Assistente    Sistemas de Informação      Graduação    3704.970000         175.209222       416.32
# 974        975  Funcionário 975      Masculino    Operações     Analista                 Logística      Tecnólogo    3446.590000         175.209222       396.03
# 975        976  Funcionário 976       Feminino    Operações     Analista    Engenharia de Produção      Graduação    5212.500000         203.100000       315.31
# 976        977  Funcionário 977      Masculino           RH   Assistente                Psicologia      Tecnólogo    4983.300000         176.900000       300.14
# 977        978  Funcionário 978       Feminino    Marketing      Gerente             Administração   Ensino Médio    7016.110000         175.209222       574.99
# 978        979  Funcionário 979      Masculino           RH     Analista             Administração   Ensino Médio    5750.030000         175.209222       359.13
# 979        980  Funcionário 980      Masculino           RH   Assistente          Recursos Humanos      Doutorado    2852.300000         177.000000       714.94
# 980        981  Funcionário 981       Feminino   Financeiro  Coordenador                  Economia      Graduação    4056.530000         135.400000       374.54
# 981        982  Funcionário 982      Masculino           RH     Analista             Administração      Graduação    6605.110000         177.800000       806.80
# 982        983  Funcionário 983      Masculino           TI   Assistente    Sistemas de Informação      Graduação    4068.380000         149.700000       583.55
# 983        984  Funcionário 984      Masculino   Financeiro     Analista             Contabilidade      Graduação    7601.860000         158.300000       551.68
# 984        985  Funcionário 985       Feminino           TI   Assistente     Ciência da Computação  Pós-graduação    3352.570000         162.600000       269.91
# 985        986  Funcionário 986  Não Informado           RH   Assistente                Psicologia  Pós-graduação    5858.920000         142.400000       565.82
# 986        987  Funcionário 987      Masculino    Operações   Assistente                 Logística  Pós-graduação    3708.180000         133.300000       509.10
# 987        988  Funcionário 988  Não Informado   Financeiro      Gerente             Administração      Graduação    4235.610000         167.400000       626.42
# 988        989  Funcionário 989      Masculino    Operações  Coordenador                 Logística      Graduação    6647.870000         132.200000       397.83
# 990        991  Funcionário 991       Feminino           TI   Assistente  Engenharia da Computação   Ensino Médio    6220.180000         143.300000       555.04
# 991        992  Funcionário 992  Não Informado   Financeiro     Analista             Administração  Pós-graduação    5709.940000         166.600000      -248.02
# 992        993  Funcionário 993      Masculino           TI   Assistente    Sistemas de Informação      Tecnólogo    6130.800000         154.600000       548.78
# 993        994  Funcionário 994       Feminino   Financeiro     Analista             Administração      Graduação    3667.720000         185.300000       701.13
# 994        995  Funcionário 995      Masculino           TI   Assistente  Engenharia da Computação      Graduação    4667.640000         163.700000       312.07
# 995        996  Funcionário 996      Masculino    Operações   Assistente    Engenharia de Produção   Ensino Médio    5636.380000         144.700000        23.65
# 996        997  Funcionário 997      Masculino    Marketing     Analista        Comunicação Social      Tecnólogo    3726.390000         151.200000       595.01
# 997        998  Funcionário 998       Feminino           RH      Gerente                Psicologia   Ensino Médio    7444.250000         131.300000       581.18
# 998        999  Funcionário 999  Não Informado           RH   Assistente          Recursos Humanos   Ensino Médio    3834.160000         181.700000       404.59
#
# Informações Gerais do Dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 963 entries, 0 to 998
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Matricula          963 non-null    int64
#  1   Nome               963 non-null    object
#  2   Genero             963 non-null    object
#  3   Departamento       963 non-null    object
#  4   Cargo              963 non-null    object
#  5   Formacao           963 non-null    object
#  6   Escolaridade       963 non-null    object
#  7   Salario_Bruto      963 non-null    float64
#  8   Horas_Trabalhadas  963 non-null    float64
#  9   Bonificacao        963 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 82.8+ KB
# None

# %% [markdown]
# ## Etapa 7: Clusterização

# %% [markdown]
# ### Técnicas para identificação do hiperparametro K

# %%
# Selecionar as colunas numéricas relevantes para a clusterização
features_cluster = dataset[['Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao']]

# Normalizar os dados
scaler = MinMaxScaler()
features_cluster = scaler.fit_transform(features_cluster)

# Encontrar o número ótimo de clusters usando a técnica do cotovelo
inertia = []
for i in range(1, 10):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(features_cluster)
    inertia.append(kmeans.inertia_)

# Plotar o gráfico do cotovelo
plt.plot(range(1, 10), inertia, marker='o')
plt.title('Método do Cotovelo')
plt.xlabel('Número de Clusters')
plt.ylabel('Inércia')
plt.show()

# Exemplo de heurística (pode ser ajustado conforme necessário)
elbow_point = np.argmax(np.diff(inertia) / inertia[:-1] * -1) + 1

print(f"O número ideal de clusters (método do cotovelo) é: {elbow_point}")
# Out:
# O número ideal de clusters (método do cotovelo) é: 2

# %% [markdown]
# **Explicação**: Encontrar o número de clusters com o "cotovelo" mais eficaz, pois o ponto onde a curva começa a se achatar é a melhor indicação visual, porém pode-se usar uma heurística, por exemplo, a maior diferença na redução da inércia entre dois clusters consecutivos.

# %%
# Selecionar as colunas numéricas relevantes para a clusterização
features_cluster = dataset[['Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao']]

# Normalizar os dados
scaler = MinMaxScaler()
features_cluster = scaler.fit_transform(features_cluster)

# Encontrar o número ótimo de clusters usando a técnica de silhueta
silhouette_scores = []
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(features_cluster)
    silhouette_avg = silhouette_score(features_cluster, labels)
    silhouette_scores.append(silhouette_avg)

# Plotar os resultados da silhueta
plt.plot(range(2, 10), silhouette_scores, marker='o')
plt.xlabel('Número de Clusters')
plt.ylabel('Pontuação da Silhueta')
plt.title('Método da Silhueta para encontrar o Número Ideal de Clusters')
plt.show()

# Encontrar o número de clusters com a maior pontuação de silhueta
best_n_clusters = np.argmax(silhouette_scores) + 2

print(f"O número ideal de clusters é: {best_n_clusters}")
# Out:
# O número ideal de clusters é: 3

# %% [markdown]
# ### Algoritmo de Clusterização (KMeans)

# %%
# Definir os hiperparâmetros do KMeans
n_clusters = 3  # Número de clusters (K)
max_iter = 200  # Número máximo de iterações
init = 'k-means++'  # Método de inicialização dos centróides
n_init = 10  # Número de vezes que o algoritmo KMeans será executado com diferentes inicializações
algorithm = 'lloyd' # Algoritmo para calcular os centróides ('lloyd' ou 'elkan' ou 'auto')

# Criar o modelo KMeans com os hiperparâmetros definidos
kmeans = KMeans(n_clusters=n_clusters, max_iter=max_iter, init=init, n_init=n_init, algorithm=algorithm, random_state=42)

# Selecionar as colunas numéricas relevantes para a clusterização
features_cluster = dataset[['Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao']]

# Normalizar os dados (opcional, mas recomendado para KMeans)
scaler = MinMaxScaler()
features_cluster = scaler.fit_transform(features_cluster)

# Executar a clusterização
kmeans.fit(features_cluster)

# Obter as etiquetas dos clusters para cada ponto de dados
labels = kmeans.labels_

# Obter as coordenadas dos centróides dos clusters
centroids = kmeans.cluster_centers_

# %%
# Criar o gráfico de dispersão
plt.figure(figsize=(10, 6))

# Plotar os dados de cada cluster com cores diferentes
for i in range(n_clusters):
  plt.scatter(features_cluster[labels == i, 0], features_cluster[labels == i, 1], label=f'Cluster {i+1}')

# Plotar os centróides dos clusters com um marcador especial (estrela)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=200, c='red', label='Centróides')

plt.xlabel('Salario_Bruto')
plt.ylabel('Horas_Trabalhadas')
plt.title('Clusterização com K-Means')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Exibir os dados referentes a cada cluster de forma dinâmica (opcional)
for i in range(3):
  print(f"\nDados do Cluster {i+1}:")
  cluster_data = dataset[labels == i]
  print(cluster_data.describe().to_string())
# Out:
# Dados do Cluster 1:
#         Matricula  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# count  442.000000     442.000000         442.000000   442.000000
# mean   491.615385    5112.444761         174.587294   522.365837
# std    280.375108    1335.265052           9.739121   186.313535
# min      7.000000    1188.140000         158.300000   147.550000
# 25%    254.500000    4239.425000         167.825000   381.840000
# 50%    479.000000    5297.610000         175.209222   520.680000
# 75%    734.750000    5780.980000         178.425000   651.047500
# max    999.000000    9020.860000         206.300000  1032.550000
#
# Dados do Cluster 2:
#         Matricula  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# count  116.000000     116.000000         116.000000   116.000000
# mean   496.620690    5151.521954         162.865609  -161.841983
# std    284.323137    1252.531142          14.309619   148.801350
# min     12.000000    2213.780000         115.900000  -248.020000
# 25%    248.750000    4241.257500         155.350000  -248.020000
# 50%    485.500000    5213.915000         165.700000  -248.020000
# 75%    754.250000    5885.410000         173.650000   -86.790000
# max    996.000000    8348.020000         192.600000   163.360000
#
# Dados do Cluster 3:
#         Matricula  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# count  405.000000     405.000000         405.000000   405.000000
# mean   507.125926    4961.657905         143.589136   510.701383
# std    294.065816    1398.294424          11.197068   184.586671
# min      1.000000    1198.170000         105.600000   111.890000
# 25%    253.000000    3890.100000         136.600000   376.040000
# 50%    519.000000    5039.370000         145.800000   504.960000
# 75%    758.000000    5769.080000         152.100000   636.030000
# max    998.000000    9393.640000         160.300000  1185.510000

# %%
# Exibir os dados dos clusters
for i in range(3):  # Itere pelos clusters (assumindo 3 clusters)
  print(f"\nHead do Cluster {i+1}:")
  cluster_data = dataset[labels == i].head()
  print(cluster_data.to_string())
# Out:
# Head do Cluster 1:
#     Matricula            Nome         Genero Departamento       Cargo                  Formacao  Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 6           7   Funcionário 7  Não Informado    Marketing     Diretor        Comunicação Social  Ensino Médio        5379.21              188.4       725.94
# 8           9   Funcionário 9      Masculino    Operações  Assistente    Engenharia de Produção  Ensino Médio        7661.99              173.6       494.84
# 12         13  Funcionário 13  Não Informado           TI     Gerente  Engenharia da Computação      Mestrado        5495.80              179.8       716.19
# 21         22  Funcionário 22       Feminino   Financeiro  Assistente             Administração      Mestrado        2625.97              175.6       522.46
# 22         23  Funcionário 23       Feminino    Marketing     Gerente                 Marketing     Tecnólogo        6440.84              163.7       578.47
#
# Head do Cluster 2:
#     Matricula            Nome         Genero Departamento        Cargo                  Formacao  Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 11         12  Funcionário 12  Não Informado    Operações  Coordenador                 Logística     Graduação        6154.15         171.300000      -248.02
# 34         35  Funcionário 35  Não Informado           RH      Diretor          Recursos Humanos  Ensino Médio        4562.54         175.209222       125.38
# 36         37  Funcionário 37       Feminino           TI     Analista  Engenharia da Computação  Ensino Médio        3829.54         171.900000      -248.02
# 44         45  Funcionário 45       Feminino   Financeiro     Analista             Contabilidade  Ensino Médio        4116.16         175.209222      -248.02
# 46         47  Funcionário 47      Masculino   Financeiro  Coordenador             Contabilidade     Tecnólogo        5197.36         170.100000      -248.02
#
# Head do Cluster 3:
#    Matricula           Nome         Genero Departamento        Cargo                Formacao   Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 0          1  Funcionário 1       Feminino    Operações      Diretor  Engenharia de Produção  Pós-graduação    5599.508789              139.9       315.92
# 1          2  Funcionário 2       Feminino   Financeiro     Analista           Administração  Pós-graduação    5128.930000              117.1       467.94
# 3          4  Funcionário 4  Não Informado    Marketing  Coordenador               Marketing      Tecnólogo    5844.480000              155.9       199.47
# 4          5  Funcionário 5  Não Informado    Marketing      Gerente      Comunicação Social      Graduação    3207.520000              151.0       318.89
# 5          6  Funcionário 6      Masculino           RH      Diretor              Psicologia       Mestrado    4249.390000              156.0       553.01

# %%
# Adicionar a coluna de clusters ao dataset
dataset['Cluster'] = labels

# Criar o gráfico de distribuição dos salários brutos por cluster
plt.figure(figsize=(10, 6))
for cluster in dataset['Cluster'].unique():
  plt.hist(dataset[dataset['Cluster'] == cluster]['Salario_Bruto'], alpha=0.5, label=f'Cluster {cluster + 1}')

plt.xlabel('Salário Bruto')
plt.ylabel('Frequência')
plt.title('Distribuição de Salários Brutos por Cluster')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Etapa 8: Rotulagem

# %%
# Adicionar a coluna 'Nivel' ao dataset com base nos clusters
dataset['Nivel'] = dataset['Cluster'].map({
    0: 'Sênior',
    2: 'Pleno',
    1: 'Junior'
})

# Selecionar as colunas desejadas e na ordem especificada
dataset = dataset[['Nivel', 'Matricula', 'Nome', 'Genero', 'Departamento', 'Cargo', 'Formacao', 'Escolaridade', 'Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao']]

# %%
# Exibir o dataset com a nova coluna e ordem de colunas
print(dataset.head().to_string())
# Out:
#    Nivel  Matricula           Nome         Genero Departamento        Cargo                Formacao   Escolaridade  Salario_Bruto  Horas_Trabalhadas  Bonificacao
# 0  Pleno          1  Funcionário 1       Feminino    Operações      Diretor  Engenharia de Produção  Pós-graduação    5599.508789              139.9       315.92
# 1  Pleno          2  Funcionário 2       Feminino   Financeiro     Analista           Administração  Pós-graduação    5128.930000              117.1       467.94
# 3  Pleno          4  Funcionário 4  Não Informado    Marketing  Coordenador               Marketing      Tecnólogo    5844.480000              155.9       199.47
# 4  Pleno          5  Funcionário 5  Não Informado    Marketing      Gerente      Comunicação Social      Graduação    3207.520000              151.0       318.89
# 5  Pleno          6  Funcionário 6      Masculino           RH      Diretor              Psicologia       Mestrado    4249.390000              156.0       553.01

# %% [markdown]
# ## Etapa 9: Preprocess

# %%
# Converter variáveis categóricas para numéricas usando one-hot encoding
dataset = pd.get_dummies(dataset, columns=['Genero', 'Departamento', 'Cargo', 'Formacao', 'Escolaridade'])

# Normalizar os dados numéricos usando MinMaxScaler
numerical_features = ['Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao']
scaler = MinMaxScaler()
dataset[numerical_features] = scaler.fit_transform(dataset[numerical_features])

# %%
# Listar os dados do dataset transformado
print(dataset.head().to_string())
# Out:
#    Nivel  Matricula           Nome  Salario_Bruto  Horas_Trabalhadas  Bonificacao  Genero_Feminino  Genero_Masculino  Genero_Não Informado  Departamento_Financeiro  Departamento_Marketing  Departamento_Operações  Departamento_RH  Departamento_TI  Cargo_Analista  Cargo_Assistente  Cargo_Coordenador  Cargo_Diretor  Cargo_Gerente  Formacao_Administração  Formacao_Ciência da Computação  Formacao_Comunicação Social  Formacao_Contabilidade  Formacao_Economia  Formacao_Engenharia da Computação  Formacao_Engenharia de Produção  Formacao_Logística  Formacao_Marketing  Formacao_Psicologia  Formacao_Publicidade e Propaganda  Formacao_Recursos Humanos  Formacao_Sistemas de Informação  Escolaridade_Doutorado  Escolaridade_Ensino Médio  Escolaridade_Graduação  Escolaridade_Mestrado  Escolaridade_Pós-graduação  Escolaridade_Tecnólogo
# 0  Pleno          1  Funcionário 1       0.537611           0.340616     0.393393             True             False                 False                    False                   False                    True            False            False           False             False              False           True          False                   False                           False                        False                   False              False                              False                             True               False               False                False                              False                      False                            False                   False                      False                   False                  False                        True                   False
# 1  Pleno          2  Funcionário 2       0.480262           0.114201     0.499438             True             False                 False                     True                   False                   False            False            False            True             False              False          False          False                    True                           False                        False                   False              False                              False                            False               False               False                False                              False                      False                            False                   False                      False                   False                  False                        True                   False
# 3  Pleno          4  Funcionário 4       0.567466           0.499503     0.312159            False             False                  True                    False                    True                   False            False            False           False             False               True          False          False                   False                           False                        False                   False              False                              False                            False               False                True                False                              False                      False                            False                   False                      False                   False                  False                       False                    True
# 4  Pleno          5  Funcionário 5       0.246101           0.450844     0.395464            False             False                  True                    False                    True                   False            False            False           False             False              False          False           True                   False                           False                         True                   False              False                              False                            False               False               False                False                              False                      False                            False                   False                      False                    True                  False                       False                   False
# 5  Pleno          6  Funcionário 6       0.373073           0.500497     0.558781            False              True                 False                    False                   False                   False             True            False           False             False              False           True          False                   False                           False                        False                   False              False                              False                            False               False               False                 True                              False                      False                            False                   False                      False                   False                   True                       False                   False

# %%
# Listar os nomes dos metadados do dataset
print(dataset.columns.tolist())
# Out:
# ['Nivel', 'Matricula', 'Nome', 'Salario_Bruto', 'Horas_Trabalhadas', 'Bonificacao', 'Genero_Feminino', 'Genero_Masculino', 'Genero_Não Informado', 'Departamento_Financeiro', 'Departamento_Marketing', 'Departamento_Operações', 'Departamento_RH', 'Departamento_TI', 'Cargo_Analista', 'Cargo_Assistente', 'Cargo_Coordenador', 'Cargo_Diretor', 'Cargo_Gerente', 'Formacao_Administração', 'Formacao_Ciência da Computação', 'Formacao_Comunicação Social', 'Formacao_Contabilidade', 'Formacao_Economia', 'Formacao_Engenharia da Computação', 'Formacao_Engenharia de Produção', 'Formacao_Logística', 'Formacao_Marketing', 'Formacao_Psicologia', 'Formacao_Publicidade e Propaganda', 'Formacao_Recursos Humanos', 'Formacao_Sistemas de Informação', 'Escolaridade_Doutorado', 'Escolaridade_Ensino Médio', 'Escolaridade_Graduação', 'Escolaridade_Mestrado', 'Escolaridade_Pós-graduação', 'Escolaridade_Tecnólogo']

# %%
# Definir atributos como features, target e metadados
features = dataset.drop(['Nivel', 'Matricula', 'Nome'], axis=1)
target = dataset['Nivel']
meta = dataset[['Matricula', 'Nome']]

# Converter variáveis categóricas para numéricas usando one-hot encoding
features = pd.get_dummies(features)

# %%
# Exibir as regras (target, meta e features) dos campos do dataset
print("\nRegras dos Campos do Dataset:")
print("--------------------------")
print("\nTarget (variável alvo):")
print(target.name)
print("\nMetadados:")
for column in meta.columns:
    print(column)
print("\nFeatures (variáveis preditoras):")
for column in features.columns:
    print(column)
# Out:
# Regras dos Campos do Dataset:
# --------------------------
#
# Target (variável alvo):
# Nivel
#
# Metadados:
# Matricula
# Nome
#
# Features (variáveis preditoras):
# Salario_Bruto
# Horas_Trabalhadas
# Bonificacao
# Genero_Feminino
# Genero_Masculino
# Genero_Não Informado
# Departamento_Financeiro
# Departamento_Marketing
# Departamento_Operações
# Departamento_RH
# Departamento_TI
# Cargo_Analista
# Cargo_Assistente
# Cargo_Coordenador
# Cargo_Diretor
# Cargo_Gerente
# Formacao_Administração
# Formacao_Ciência da Computação
# Formacao_Comunicação Social
# Formacao_Contabilidade
# Formacao_Economia
# Formacao_Engenharia da Computação
# Formacao_Engenharia de Produção
# Formacao_Logística
# Formacao_Marketing
# Formacao_Psicologia
# Formacao_Publicidade e Propaganda
# Formacao_Recursos Humanos
# Formacao_Sistemas de Informação
# Escolaridade_Doutorado
# Escolaridade_Ensino Médio
# Escolaridade_Graduação
# Escolaridade_Mestrado
# Escolaridade_Pós-graduação
# Escolaridade_Tecnólogo

# %% [markdown]
# ## Etapa 10: Balanceamento dos Dados

# %%
# Contar a quantidade de exemplos por classe
target_counts = target.value_counts()

print("\nQuantidade de Exemplos por Classe Alvo:")
target_counts
# Out:
# Quantidade de Exemplos por Classe Alvo:
# Nivel
# Sênior    442
# Pleno     405
# Junior    116
# Name: count, dtype: int64

# %%
# Contar a quantidade de exemplos por classe no atributo 'Pontuacao_Credito'
target_counts = target.value_counts()

# Encontrar a classe minoritária
minority_class = target_counts.idxmin()

# Encontrar a quantidade de exemplos da classe minoritária
n_samples_minority = target_counts.min()

# Criar um DataFrame vazio para armazenar o conjunto de dados balanceado
balanced_dataset = pd.DataFrame()

# Balancear os dados para cada classe
for class_label in target_counts.index:
  # Filtrar os dados para a classe atual
  class_data = dataset[dataset['Nivel'] == class_label]

  # Se a classe for a minoritária, manter todos os exemplos
  if class_label == minority_class:
    balanced_dataset = pd.concat([balanced_dataset, class_data])
  else:
    # Se a classe for a majoritária, fazer o downsample para o número de exemplos da classe minoritária
    downsampled_class_data = resample(class_data,
                                     replace=False,
                                     n_samples=n_samples_minority,
                                     random_state=42)
    balanced_dataset = pd.concat([balanced_dataset, downsampled_class_data])

# Redefinir o índice do conjunto de dados balanceado
balanced_dataset = balanced_dataset.reset_index(drop=True)

# Exibir a quantidade de exemplos por classe no conjunto de dados balanceado
print("\nQuantidade de Exemplos por Classe Alvo (Dataset Balanceado):")
print(balanced_dataset['Nivel'].value_counts())
# Out:
# Quantidade de Exemplos por Classe Alvo (Dataset Balanceado):
# Nivel
# Sênior    116
# Pleno     116
# Junior    116
# Name: count, dtype: int64

# %% [markdown]
# ## Etapa 11: Separação dos Dados para Treinamento/Teste e Validação

# %%
# Definir atributos como features, target e metadados
features = balanced_dataset.drop(['Nivel', 'Matricula', 'Nome'], axis=1)
target = balanced_dataset['Nivel']
meta = balanced_dataset[['Matricula', 'Nome']]

# Dividir o dataset em conjuntos de treinamento e teste (80% para treinamento, 20% para teste)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42, stratify=target)

# Exibir as dimensões dos conjuntos de treinamento e teste
print("Dimensões do conjunto de treinamento (X_train):", X_train.shape)
print("Dimensões do conjunto de teste (X_test):", X_test.shape)
# Out:
# Dimensões do conjunto de treinamento (X_train): (278, 35)
# Dimensões do conjunto de teste (X_test): (70, 35)

# %% [markdown]
# ## Etapa 12: Competição dos Modelos

# %%
# Criar modelo SVM com hiperparâmetros específicos
svm_model = SVC(
    C=1.0,  # Parâmetro de regularização (custo da classificação incorreta)
    kernel='rbf',  # Kernel para o modelo (radial basis function)
    degree=3,  # Grau do polinômio para o kernel (relevante para kernel='poly')
    gamma='scale',  # Coeficiente do kernel (relevante para kernel='rbf', 'poly', 'sigmoid')
    coef0=0.0,  # Termo independente para o kernel (relevante para kernel='poly', 'sigmoid')
    shrinking=True,  # Utilização do shrinking heuristic para otimizar a solução
    probability=False,  # Calcular probabilidades de classe
    tol=0.001,  # Tolerância para a otimização
    cache_size=1000,  # Tamanho do cache em MB
    class_weight=None,  # Pesos para as classes (pode ser usado para lidar com classes desbalanceadas)
    verbose=False,  # Mostrar mensagens durante a execução
    max_iter=200,  # Número máximo de iterações para a otimização (-1 significa ilimitado)
    decision_function_shape='ovr',  # Formato da função de decisão ('ovo' para one-vs-one, 'ovr' para one-vs-rest)
    break_ties=False,  # Quebrar empates com maior precisão (relevante para classificação multiclasse)
    random_state=None  # Semente aleatória para reprodutibilidade
)

# %%
# Criar um modelo MLP com hiperparâmetros específicos
mlp_model = MLPClassifier(
    hidden_layer_sizes=(100,),  # Número de neurônios em cada camada oculta
    activation='relu',  # Função de ativação
    solver='adam',  # Algoritmo de otimização
    alpha=0.0001,  # Termo de regularização L2
    batch_size='auto',  # Tamanho do batch para o treinamento
    learning_rate='constant',  # Taxa de aprendizado
    learning_rate_init=0.001,  # Taxa de aprendizado inicial
    power_t=0.5,  # Parâmetro para o algoritmo de otimização 'sgd'
    max_iter=1000,  # Número máximo de iterações
    shuffle=True,  # Embaralhar os dados a cada época
    random_state=None,  # Semente aleatória
    tol=0.0001,  # Tolerância para o critério de parada
    verbose=False,  # Mostrar mensagens durante o treinamento
    warm_start=False,  # Reutilizar a solução da inicialização anterior
    momentum=0.9,  # Parâmetro para o algoritmo de otimização 'sgd'
    nesterovs_momentum=True,  # Utilizar o momentum de Nesterov
    early_stopping=False,  # Parar o treinamento precocemente
    validation_fraction=0.1,  # Fração de dados para validação
    beta_1=0.9,  # Parâmetro para o algoritmo de otimização 'adam'
    beta_2=0.999,  # Parâmetro para o algoritmo de otimização 'adam'
    epsilon=1e-08,  # Parâmetro para o algoritmo de otimização 'adam'
    n_iter_no_change=10,  # Número máximo de épocas sem melhoria
    max_fun=15000  # Número máximo de chamadas para a função de custo
)

# %%
# Define the number of folds for cross-validation
n_folds = 3

# Create StratifiedKFold object for cross-validation
cv = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)

# Function to evaluate the model and print the results
def evaluate_model(model, X, y, cv):
  accuracy_scores = []
  precision_scores = []
  recall_scores = []
  f1_scores = []

  for train_index, test_index in cv.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy_scores.append(accuracy_score(y_test, y_pred))
    precision_scores.append(precision_score(y_test, y_pred, average='weighted'))
    recall_scores.append(recall_score(y_test, y_pred, average='weighted'))
    f1_scores.append(f1_score(y_test, y_pred, average='weighted'))

  print("Accuracy:", np.mean(accuracy_scores))
  print("Precision:", np.mean(precision_scores))
  print("Recall:", np.mean(recall_scores))
  print("F1-Score:", np.mean(f1_scores))

# Evaluate the SVM model
print("SVM Model Evaluation:")
evaluate_model(svm_model, X_train, y_train, cv)

# Evaluate the MLP model
print("\nMLP Model Evaluation:")
evaluate_model(mlp_model, X_train, y_train, cv)
# Out:
# SVM Model Evaluation:
# Accuracy: 0.600709054075113
# Precision: 0.6062059082892416
# Recall: 0.600709054075113
# F1-Score: 0.5979712637624007
#
# MLP Model Evaluation:
# Accuracy: 0.7015349851955742
# Precision: 0.7034579871984331
# Recall: 0.7015349851955742
# F1-Score: 0.7003267857915955

# %%
# Fazer previsões no conjunto de teste
y_pred = mlp_model.predict(X_test)

# Calcular as métricas de avaliação
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Exibir as métricas
print("Métricas do Modelo MLP:")
print("Acurácia:", accuracy)
print("Precisão:", precision)
print("Revocação:", recall)
print("F1-Score:", f1)
# Out:
# Métricas do Modelo MLP:
# Acurácia: 0.7428571428571429
# Precisão: 0.7558210180623973
# Revocação: 0.7428571428571429
# F1-Score: 0.7452784600217685
